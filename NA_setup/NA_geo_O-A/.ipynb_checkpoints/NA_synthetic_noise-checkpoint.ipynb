# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import statistics as st
from astropy.io import ascii
import sys
import imp
from tqdm import tqdm
sys.path.insert(0, '/Users/H/INVERSE/Python/')

import freedrift
imp.reload(freedrift)
# from scipy.io import FortranFile
# import struct
# Out:
# <module 'freedrift' from '/Users/H/INVERSE/Python/freedrift.py'>

# %%
location =  % pwd
location
# Out:
# '/Users/H/INVERSE/Code_dev/NA_geo'

# %%
# constants
rhoa = 1.25 
rhoi = 917.0 
rhoo = 1026.0 
fc   = 1.46e-4 

# going to pass N2a and rop ranges directly now

Ca     = 5e-3
ThetaA = np.deg2rad(5)
Co     = 1e-2
ThetaO = np.deg2rad(20) # original

# invert for thO and thA-thO
# # these replace for thO
# thA_min = ThetaO - np.deg2rad(90)
# thA_max = ThetaO + np.deg2rad(90)
# # these replace for thA-thO
# thO_min = (ThetaA - ThetaO) - np.deg2rad(90)
# thO_max = (ThetaA - ThetaO) + np.deg2rad(90)
# these replace for thO
thA_min =  - np.deg2rad(90)
thA_max =  + np.deg2rad(90)
# these replace for thA-thO
thO_min =  - np.deg2rad(90)
thO_max =  + np.deg2rad(90)


nansen_use = freedrift.nansen(Ca,Co)**2
rossby_use = freedrift.rossby_pp(Co)
n2a_min = nansen_use*1e-1
n2a_max = nansen_use*2e0
rop_min = rossby_use*1e-1
rop_max = rossby_use*4e0
# n2a_min = nansen_use-1e-4
# n2a_max = nansen_use+1e-4
# rop_min = rossby_use*1e-1
# rop_max = rossby_use*1e2
print(n2a_min, np.sqrt(nansen_use), nansen_use, n2a_max)
print(rop_min, rossby_use, rop_max)
# Out:
# 6.09161793372e-05 0.02468120324 0.000609161793372 0.00121832358674
# 8.937621832358674 89.37621832358674 357.50487329434696

# %%
nbals = 5
hice = np.ndarray([nbals])
hifc = np.ndarray([nbals])
hice[0] = 1.0e-0
hifc[0] = hice[0]*fc
hice[1] = 1.0e-0
hifc[1] = hice[1]*fc
hice[2] = 0.9e-0
hifc[2] = hice[2]*fc
hice[3] = 0.9e-0
hifc[3] = hice[3]*fc
hice[4] = 1.0e-0
hifc[4] = hice[4]*fc

# %%
# changing to dimensional errors
wind_mag = np.ndarray([nbals])
wind_ang = np.ndarray([nbals])
wind_sig = np.ndarray([nbals])
uwind = np.ndarray([nbals])
vwind = np.ndarray([nbals])
ice_mag = np.ndarray([nbals])
ice_ang = np.ndarray([nbals])
ice_sig = np.ndarray([nbals])
uice = np.ndarray([nbals])
vice = np.ndarray([nbals])
ocn_mag = np.ndarray([nbals])
ocn_ang = np.ndarray([nbals])
ocn_sig = np.ndarray([nbals])
uocn = np.ndarray([nbals])
vocn = np.ndarray([nbals])
# set up wind and ocean
wind_mag[0] = 1.1
wind_ang[0] = np.deg2rad(0)
wind_sig[0] = 0.1*wind_mag[0]
uwind[0]    = wind_mag[0]*np.cos(wind_ang[0])
vwind[0]    = wind_mag[0]*np.sin(wind_ang[0])
ocn_mag[0]  = 0.1
ocn_ang[0]  = np.deg2rad(10)
ocn_sig[0] = 0.01*ocn_mag[0]  
uocn[0]     = ocn_mag[0]*np.cos(ocn_ang[0])
vocn[0]     = ocn_mag[0]*np.sin(ocn_ang[0])

wind_mag[1] = 2.1
wind_ang[1] = np.deg2rad(15)
wind_sig[1] = 0.1*wind_mag[1]
uwind[1]    = wind_mag[1]*np.cos(wind_ang[1])
vwind[1]    = wind_mag[1]*np.sin(wind_ang[1])
ocn_mag[1]  = 0.02
ocn_ang[1]  = np.deg2rad(-49)
ocn_sig[1] = 0.01*ocn_mag[1]
uocn[1]     = ocn_mag[1]*np.cos(ocn_ang[1])
vocn[1]     = ocn_mag[1]*np.sin(ocn_ang[1])

wind_mag[2] = 0.6
wind_ang[2] = np.deg2rad(110)
wind_sig[2] = 0.1*wind_mag[2]
uwind[2]    = wind_mag[2]*np.cos(wind_ang[2])
vwind[2]    = wind_mag[2]*np.sin(wind_ang[2])
ocn_mag[2]  = 0.06
ocn_ang[2]  = np.deg2rad(63)
ocn_sig[2] = 0.01*ocn_mag[2]
uocn[2]     = ocn_mag[2]*np.cos(ocn_ang[2])
vocn[2]     = ocn_mag[2]*np.sin(ocn_ang[2])

wind_mag[3] = 0.5
wind_ang[3] = np.deg2rad(12)
wind_sig[3] = 0.1*wind_mag[3]
uwind[3]    = wind_mag[3]*np.cos(wind_ang[3])
vwind[3]    = wind_mag[3]*np.sin(wind_ang[3])
ocn_mag[3]  = 0.03
ocn_ang[3]  = np.deg2rad(135)
ocn_sig[3] = 0.01*ocn_mag[3]
uocn[3]     = ocn_mag[3]*np.cos(ocn_ang[3])
vocn[3]     = ocn_mag[3]*np.sin(ocn_ang[3])

wind_mag[4] = 4.0
wind_ang[4] = np.deg2rad(1)
wind_sig[4] = 0.1*wind_mag[4]
uwind[4]    = wind_mag[4]*np.cos(wind_ang[4])
vwind[4]    = wind_mag[4]*np.sin(wind_ang[4])
ocn_mag[4]  = 0.001
ocn_ang[4]  = np.deg2rad(-114)
ocn_sig[4] = 0.1*ocn_mag[4]
uocn[4]     = ocn_mag[4]*np.cos(ocn_ang[4])
vocn[4]     = ocn_mag[4]*np.sin(ocn_ang[4])

# Ca_min = 1.0e-6
# Ca_max = 2.0e-3
# Co_min = 1.0e-3
# Co_max = 6.0e-2

# %%
# now generate arbitrary synthetic values
# generate wnd and geo and create the o_i
nbals = 20
hice = np.ndarray([nbals])
hifc = np.ndarray([nbals])
wind_mag = np.ndarray([nbals])
wind_ang = np.ndarray([nbals])
wind_sig = np.ndarray([nbals])
uwind = np.ndarray([nbals])
vwind = np.ndarray([nbals])
ice_mag = np.ndarray([nbals])
ice_ang = np.ndarray([nbals])
uice = np.ndarray([nbals])
vice = np.ndarray([nbals])
geo_mag = np.ndarray([nbals])
geo_ang = np.ndarray([nbals])
ugeo = np.ndarray([nbals])
vgeo = np.ndarray([nbals])
for i in range(nbals):
    wind_mag[i] = np.random.normal(loc=3.0,scale=3)
#     wind_mag[i] = np.random.uniform(0,10.0)
    wind_mag[i] = np.max([wind_mag[i],0.5])
    wind_ang[i] = np.random.uniform(-90,90)
    uwind[i]    = wind_mag[i]*np.cos(np.deg2rad(wind_ang[i]))
    vwind[i]    = wind_mag[i]*np.sin(np.deg2rad(wind_ang[i]))
    geo_mag[i]  = np.random.normal(loc=0.04,scale=0.04)
    geo_mag[i] = np.max([geo_mag[i],0.005])
#     geo_ang[i] = np.random.uniform(-45,135)
    geo_ang[i] = np.random.uniform(-50,50)
    ugeo[i]     = geo_mag[i]*np.cos(np.deg2rad(geo_ang[i]))
    vgeo[i]     = geo_mag[i]*np.sin(np.deg2rad(geo_ang[i]))
    hice[i] = np.random.normal(loc=0.9,scale=0.3)
    hice[i] = np.max([hice[i],0.5])
    hifc[i] = hice[i]*fc

# %%
ice_ocn_mag = np.ndarray([nbals])
na2 = np.ndarray([nbals])
rop = np.ndarray([nbals])
thA = np.ndarray([nbals])
thO = np.ndarray([nbals])
o_i_mag = np.ndarray([nbals])
o_i_sig = np.ndarray([nbals])
geo_sig = np.ndarray([nbals])
uo_i = np.ndarray([nbals])
vo_i = np.ndarray([nbals])
sig_c = 0.2# plus/minus lever for random error
sig_w = 0.2
sig_i = 0.2
sig_g = 0.2
# problem 1

for i in range(nbals):
    Na2 = freedrift.nansen(Ca,Co)**2*np.random.normal(loc=1.0,scale=sig_c)
    RoP = freedrift.rossby_pp(Co)*hifc[i]*np.random.normal(loc=1.0,scale=sig_c)
    ThA = ThetaA*np.random.normal(loc=1.0,scale=sig_c)
    ThO = ThetaO*np.random.normal(loc=1.0,scale=sig_c)
    uo_i[i],vo_i[i] = freedrift.o_i_mag_geo(uwind[i],vwind[i],ugeo[i],vgeo[i],
                 Na2,RoP,ThA,ThO)
    o_i_mag[i]     = np.hypot(uo_i[i],vo_i[i])
    wind_sig[i] = sig_w*wind_mag[i]
    o_i_sig[i] = sig_i*o_i_mag[i]
    geo_sig[i] = sig_g*geo_mag[i]
[print(wind_mag[i],o_i_mag[i],geo_mag[i],o_i_mag[i]/wind_mag[i])  for i in range(nbals)];
# [print(wind_sig[i],o_i_sig[i])  for i in range(nbals)];

# disassemble forces
# forcing_1
orig_forces = np.empty([nbals,6])
# for j in tqdm(data_NA['number']-1):
for i in range(nbals):
    orig_forces[i,:] = freedrift.force_bal_geo(
                          uwind[i],vwind[i],uo_i[i],vo_i[i],ugeo[i],vgeo[i],
                          rhoa*Ca,rhoo*Co,rhoi*hifc[i],
                          ThetaA,ThetaO)

force_magw = np.empty([nbals])
for i in range(nbals):
    force_magw[i] = np.max(np.hypot(orig_forces[i,0],orig_forces[i,1]))

wnd_scale = 1100
force_scale = 1000
# plt.figure(figsize=[10*nbals,10])
plt.figure(figsize=[25,20])
# plt.figure(figsize=[10,10])
for nb in range(nbals):
# for nb in range(3,4):
#     plt.subplot(1,nbals,nb+1)
    plt.subplot(4,5,nb+1)
#     plt.subplot(1,1,1)
    #   calculated vectors
#     for j in tqdm(range(0,data_NA['number'][-1],10)):
#         plt.arrow(0,0,wnd_scale*orig_vecs[j,nb,0],wnd_scale*orig_vecs[j,nb,1],
#                    alpha=0.009,color='k')
#         plt.arrow(0,0,orig_vecs[j,nb,2],orig_vecs[j,nb,3],
#                    alpha=0.009,color='b')
#         plt.arrow(0,0,orig_vecs[j,nb,4],orig_vecs[j,nb,5],
#                    alpha=0.009,color='g')
    plt.arrow(0,0,force_scale*orig_forces[nb,0],force_scale*orig_forces[nb,1],
               linestyle='dashed',color='k')
    plt.arrow(0,0,force_scale*orig_forces[nb,2],force_scale*orig_forces[nb,3],
               linestyle='dashed',color='b')
    plt.arrow(0,0,force_scale*orig_forces[nb,4],force_scale*orig_forces[nb,5],
               linestyle='dashed',color='g')
    #   original vectors
#     plt.arrow(0,0,wnd_scale*uwind[nb],wnd_scale*vwind[nb],color='k')
#     plt.arrow(0,0,-uo_i[nb],-vo_i[nb],color='b')
    plt.xlim([-wnd_scale*force_magw[nb],wnd_scale*force_magw[nb]])
    plt.ylim([-wnd_scale*force_magw[nb],wnd_scale*force_magw[nb]])
#     plt.xlim([-10,10])
#     plt.ylim([-10,10])
#     plt.ylim([1.1*np.min(np.hstack((wnd_scale*uwind[nb],-uo_i[nb],wnd_scale*vwind[nb],-vo_i[nb],-0.02))),
#         1.1*np.max(np.hstack((wnd_scale*uwind[nb],-uo_i[nb],wnd_scale*vwind[nb],-vo_i[nb],0.02)))]) 
plt.show()
# Out:
# 2.0328669958 0.0471336119274 0.00516008665659 0.0231857824563
# 2.35894361509 0.0573828580859 0.0561644120709 0.0243256590445
# 6.11673518803 0.170453613737 0.163781033259 0.0278667636406
# 7.7070705606 0.184626550783 0.0304071114233 0.0239554769003
# 0.487613273861 0.027653772801 0.0801609554764 0.0567125102687
# 4.87230205854 0.126940348577 0.0544101766952 0.0260534644717
# 0.513551061683 0.0348928045377 0.0711955934702 0.0679441775923
# 0.852392214456 0.0412886676802 0.141095874479 0.048438579072
# 3.49976968406 0.0880517239384 0.00470567814121 0.0251592910069
# 0.506105541393 0.00635545951117 0.0044100896878 0.0125575774051
# 3.80116168685 0.0984092780311 0.0964459208327 0.0258892638983
# 5.9456922422 0.153974138481 0.0157968706774 0.0258967555348
# 7.52290948041 0.20098803727 0.0826761609504 0.0267167959143
# 4.01669672055 0.108620801373 0.107212939063 0.0270423208249
# 3.35702153235 0.0757884253995 0.0515825921935 0.0225760915351
# 0.774485465178 0.0167674322813 0.0749167543843 0.0216497701186
# 3.28573362535 0.0706196578988 0.0212301332057 0.0214928128543
# 1.15583848715 0.0258717016103 0.0478939034796 0.0223834920691
# 1.19115933465 0.0326258772485 0.00519051777564 0.0273900193697
# 5.59924288713 0.115668074436 0.0991055304055 0.0206578062011

# %%
np.hypot(orig_forces[:,4],orig_forces[:,5])
# Out:
# array([ 0.00106869,  0.0037597 ,  0.01804301,  0.0034381 ,  0.01032194,
#         0.01037179,  0.01193744,  0.01554381,  0.00035424,  0.00054591,
#         0.01954683,  0.00189706,  0.009475  ,  0.01630622,  0.00601652,
#         0.00856098,  0.00336778,  0.00774229,  0.00062462,  0.01422316])

# %%
print(geo_mag[0])
for i in range(nbals):
    uwind[i] = uwind[i]+np.random.normal(loc=0,scale=wind_sig[i])
    vwind[i] = vwind[i]+np.random.normal(loc=0,scale=wind_sig[i])
    wind_mag[i]     = np.hypot(uwind[i],vwind[i])
    uo_i[i] = uo_i[i]+np.random.normal(loc=0,scale=o_i_sig[i])
    vo_i[i] = vo_i[i]+np.random.normal(loc=0,scale=o_i_sig[i])
    o_i_mag[i]     = np.hypot(uo_i[i],vo_i[i])
    ugeo[i] = ugeo[i]+np.random.normal(loc=0,scale=geo_sig[i])
    vgeo[i] = vgeo[i]+np.random.normal(loc=0,scale=geo_sig[i])
    geo_mag[i]     = np.hypot(ugeo[i],vgeo[i])
print(geo_mag[0])
# Out:
# 0.00516008665659
# 0.00523332925008

# %%
# try some scaling factors
Na2_scale = 0.020**2
beta_a = np.ndarray([nbals])
beta_i = np.ndarray([nbals])
beta_g = np.ndarray([nbals])
beta_fb= np.ndarray([nbals])
# for i in range(nbals):
#     beta_a[i] = o_i_mag[i]**-2*Na2_scale**3
#     beta_i[i] = wind_mag[i]**-2*Na2_scale
#     beta_g[i] = wind_mag[i]**-2*Na2_scale
#     beta_fb[i]= wind_mag[i]**-4

# ### try some scaling factors
# Na2_scale = 0.015**2
# beta_a = np.ndarray([nbals])
# beta_i = np.ndarray([nbals])
# beta_w = np.ndarray([nbals])
# beta_fb= np.ndarray([nbals])
for i in range(nbals):
    beta_a[i] = 1.0e0 # ice_ocn_mag[i]**-2*Na2_scale**3
    beta_i[i] = 1.0e0 # iwind_mag[i]**-2*Na2_scale
    beta_g[i] = 1.0e0 # iwind_mag[i]**-2*Na2_scale
    beta_fb[i]= 1.0e0 # iwind_mag[i]**-4

# aggregate errors - bad winds mean bad everything
wind_sig_use = np.ndarray([nbals])
o_i_sig_use = np.ndarray([nbals])
geo_sig_use = np.ndarray([nbals])
for i in range(nbals):
    wind_sig_use[i] = wind_sig[i]
    o_i_sig_use[i] = np.maximum(wind_sig[i]/wind_mag[i],o_i_sig[i]/o_i_mag[i])*o_i_mag[i]
    geo_sig_use[i] = np.maximum(wind_sig[i]/wind_mag[i],geo_sig[i]/geo_mag[i])*geo_mag[i]
    o_i_sig_use[i] = o_i_sig[i]
    geo_sig_use[i] = geo_sig[i]
    print([wind_sig_use[i],o_i_sig_use[i],geo_sig_use[i]])
#     wind_sig_use[i]= wind_mag[i]
#     o_i_sig_use[i] = o_i_mag[i]
#     geo_sig_use[i] = geo_mag[i]
# Out:
# [0.40657339916098617, 0.0094267223854739342, 0.0010320173313188041]
# [0.47178872301729408, 0.011476571617174469, 0.011232882414181409]
# [1.2233470376062496, 0.034090722747401249, 0.032756206651743218]
# [1.5414141121206715, 0.03692531015665567, 0.006081422284668697]
# [0.097522654772298656, 0.0055307545602036323, 0.016032191095278248]
# [0.97446041170818654, 0.025388069715473156, 0.010882035339044097]
# [0.1027102123366543, 0.006978560907544654, 0.014239118694045925]
# [0.17047844289114156, 0.0082577335360461048, 0.028219174895809818]
# [0.69995393681174845, 0.017610344787673593, 0.00094113562824126691]
# [0.10122110827866244, 0.0012710919022348314, 0.00088201793755919274]
# [0.76023233737012563, 0.019681855606212283, 0.019289184166544047]
# [1.1891384484394647, 0.030794827696228374, 0.0031593741354870859]
# [1.5045818960826032, 0.040197607454020616, 0.016535232190075296]
# [0.80333934411003194, 0.021724160274673429, 0.021442587812661618]
# [0.67140430646951932, 0.015157685079893235, 0.010316518438705492]
# [0.15489709303566376, 0.0033534864562540321, 0.014983350876855839]
# [0.65714672507010585, 0.0141239315797652, 0.0042460266411353228]
# [0.23116769743027926, 0.005174340322051444, 0.0095787806959221154]
# [0.23823186693068485, 0.0065251754497024327, 0.0010381035551279021]
# [1.1198485774263716, 0.023133614887107419, 0.019821106081102116]

# %%
its = 35
it1 = 200
itn = 100
res = 6

# open na.in
# Open file
f = open(location+'/na.in', 'r')

# Read and ignore header lines
header1 = f.readline()
header2 = f.readline()
header3 = f.readline()
header4 = f.readline()

# Loop over lines and extract variables of interest
# read p1
columns1 = f.readline()
var = columns1.split()[0]
c1_len = len(var)
# its = int(var)
# read p2
columns2 = f.readline()
var = columns2.split()[0]
c2_len = len(var)
# it1 = int(var)
# read p3
columns3 = f.readline()
var = columns3.split()[0]
c3_len = len(var)
# itn = int(var)
# read p4
columns4 = f.readline()
var = columns4.split()[0]
c4_len = len(var)
# res = int(var)

tail1 = f.readline()
tail2 = f.readline()
tail3 = f.readline()
tail4 = f.readline()
tail5 = f.readline()

f.close()
# print(its,it1,itn,res)

# write na.in
# Open file
f = open(location+'/na.in', 'w')

# write and ignore header lines
f.writelines(header1)
f.writelines(header2)
f.writelines(header3)
f.writelines(header4)

# write its
f.writelines(str(its)+columns1[c1_len:-1]+'\n')
# write it1
f.writelines(str(it1)+columns2[c2_len:-1]+'\n')
# write it1
f.writelines(str(itn)+columns3[c3_len:-1]+'\n')
# write it1
f.writelines(str(res)+columns4[c4_len:-1]+'\n')

f.writelines(tail1)
f.writelines(tail2)
f.writelines(tail3)
f.writelines(tail4)
f.writelines(tail5)

f.close()

# %%
# write freedrift_IC
data_in = np.ndarray([nbals*17+12],dtype='float32')
r = 0;
data_in[r] = nbals;r+=1
# wind data
data_in[r:r+nbals] = uwind;r+=nbals
data_in[r:r+nbals] = vwind;r+=nbals
data_in[r:r+nbals] = wind_mag;r+=nbals
data_in[r:r+nbals] = wind_sig_use;r+=nbals
# o_i data
data_in[r:r+nbals] = uo_i;r+=nbals
data_in[r:r+nbals] = vo_i;r+=nbals
data_in[r:r+nbals] = o_i_mag;r+=nbals
data_in[r:r+nbals] = o_i_sig_use;r+=nbals
# geo data
data_in[r:r+nbals] = ugeo;r+=nbals
data_in[r:r+nbals] = vgeo;r+=nbals
data_in[r:r+nbals] = geo_mag;r+=nbals
data_in[r:r+nbals] = geo_sig_use;r+=nbals
# scaling betas
data_in[r:r+nbals] = beta_a ;r+=nbals
data_in[r:r+nbals] = beta_i ;r+=nbals
data_in[r:r+nbals] = beta_g ;r+=nbals
data_in[r:r+nbals] = beta_fb;r+=nbals
# other data/constants
data_in[r:r+nbals] = hifc;r+=nbals
data_in[r] = rhoa ;r+=1
data_in[r] = rhoi ;r+=1
data_in[r] = rhoo ;r+=1
# special for range
data_in[r] = n2a_min;r+=1
data_in[r] = n2a_max;r+=1
data_in[r] = rop_min;r+=1
data_in[r] = rop_max;r+=1
data_in[r] = thA_min;r+=1
data_in[r] = thA_max;r+=1
data_in[r] = thO_min;r+=1
data_in[r] = thO_max;r+=1
# data_in[r] = thA_min/2;r+=1
# data_in[r] = thA_max/2;r+=1
# data_in[r] = thO_min/2;r+=1
# data_in[r] = thO_max/2;r+=1
f = open(location+'/freedrift_IC','wb')
data_in.tofile(f,sep=' ')
f.close()

# %%
# now run the model - freedrift_na
! bin/freedrift_na 

# convert output to ascii nad2asc
! ./nad2asc na.nad na.asc

# read output
data_NA = ascii.read(location+'/na.asc',guess=False,header_start=7,data_start=14,
                     names=['number','Na','Ro','thO','thA-O','misfit'])

##### filter misfits
misfit_filter = 1e18
misfit_min = data_NA['misfit'][0]
misfit_max = 0.0
misfit_min_no = 0
for i in data_NA['number'][0:-1]:
    if data_NA['misfit'][i] < misfit_min:
        misfit_min = data_NA['misfit'][i]
        misfit_min_no = i
    if (data_NA['misfit'][i] > misfit_max and data_NA['misfit'][i] < misfit_filter):
        misfit_max = data_NA['misfit'][i]
misfit_range = misfit_max/misfit_min
misfit_cut = misfit_min * (1.0 + misfit_range *  1e-2) 
# number_cut = int(3*data_NA['number'][-1]/4)
number_cut = 0
data_NA_cut = np.empty([6,data_NA['number'][-1]])
#
i_cut = -1
for i in data_NA['number'][number_cut:-1]:
    if data_NA['misfit'][i] < misfit_cut:
        i_cut += 1
        data_NA_cut[0,i_cut] = data_NA['number'][i]
        data_NA_cut[1,i_cut] = data_NA['Na'][i]
        data_NA_cut[2,i_cut] = data_NA['Ro'][i]
        data_NA_cut[3,i_cut] = data_NA['thO'][i]
        data_NA_cut[4,i_cut] = data_NA['thA-O'][i]
        data_NA_cut[5,i_cut] = data_NA['misfit'][i]
print(i_cut, misfit_min_no,np.mean(data_NA_cut[5,0:i_cut+1]))
# Out:
#   User routines output
#
#   Opening freedrift files...
#
#  Number of balances this time  =    20.0000000              20
#
#   Successfuly read  freedrift files...
#
#
#   Imposed Parameter space
#
#   nd = 4, Ca, thetaA, Co, thetaO
#
#   Adjusted Parameter space
#
#   nd = 4, Na, Ro,  thetaA, thetaO
#
#   Adjusted Parameter space 2
#
#   nd = 4, Na2, Ro_p,  thetaO, thetaA - thetaOO
#
#   Now invert           20  problems with same parameters
#   Problem            1
#   Wind_mag =    1.87058425
#   I_O_mag  =    4.64951955E-02
#   GEO_mag  =    5.23332926E-03
#   Problem            2
#   Wind_mag =    2.13534880
#   I_O_mag  =    5.47923036E-02
#   GEO_mag  =    6.27737418E-02
#   Problem            3
#   Wind_mag =    5.22401667
#   I_O_mag  =   0.158306494
#   GEO_mag  =   0.141839638
#   Problem            4
#   Wind_mag =    8.75150204
#   I_O_mag  =   0.250581145
#   GEO_mag  =    3.86301316E-02
#   Problem            5
#   Wind_mag =   0.640751123
#   I_O_mag  =    2.95658559E-02
#   GEO_mag  =    8.44077244E-02
#   Problem            6
#   Wind_mag =    3.26286030
#   I_O_mag  =   0.126322120
#   GEO_mag  =    5.84128834E-02
#   Problem            7
#   Wind_mag =   0.605803132
#   I_O_mag  =    3.49240862E-02
#   GEO_mag  =    7.46140927E-02
#   Problem            8
#   Wind_mag =   0.969330072
#   I_O_mag  =    4.45402004E-02
#   GEO_mag  =   0.167771176
#   Problem            9
#   Wind_mag =    4.30626202
#   I_O_mag  =    9.65214670E-02
#   GEO_mag  =    4.92391689E-03
#   Problem           10
#   Wind_mag =   0.589786589
#   I_O_mag  =    6.22369302E-03
#   GEO_mag  =    4.12016641E-03
#   Problem           11
#   Wind_mag =    3.88465548
#   I_O_mag  =   0.101215646
#   GEO_mag  =    8.96622986E-02
#   Problem           12
#   Wind_mag =    7.59590292
#   I_O_mag  =   0.193806380
#   GEO_mag  =    1.87630765E-02
#   Problem           13
#   Wind_mag =    10.2060966
#   I_O_mag  =   0.259885043
#   GEO_mag  =    7.48190507E-02
#   Problem           14
#   Wind_mag =    4.65131998
#   I_O_mag  =   0.116817184
#   GEO_mag  =    9.46989655E-02
#   Problem           15
#   Wind_mag =    4.18669462
#   I_O_mag  =    8.28556195E-02
#   GEO_mag  =    6.40214756E-02
#   Problem           16
#   Wind_mag =   0.741758227
#   I_O_mag  =    1.61589216E-02
#   GEO_mag  =    8.75980407E-02
#   Problem           17
#   Wind_mag =    4.07615709
#   I_O_mag  =    8.19590241E-02
#   GEO_mag  =    1.98005233E-02
#   Problem           18
#   Wind_mag =    1.10065317
#   I_O_mag  =    2.64568124E-02
#   GEO_mag  =    4.61194366E-02
#   Problem           19
#   Wind_mag =    1.04585469
#   I_O_mag  =    3.56061310E-02
#   GEO_mag  =    4.82146721E-03
#   Problem           20
#   Wind_mag =    5.99524164
#   I_O_mag  =   0.143452615
#   GEO_mag  =   0.105408959
#
#  -----------------------------------
#  |                                 |
#  |     Parameter space search      |
#  | using a Neighbourhood Algorithm |
#  |                                 |
#  -----------------------------------
#
#
# ------------------------------------------------------------------------
#
#   Options set:
#
#   Process                       : Neighbourhood Algorithm
#   Initial sample size           :          200
#   Sample size                   :          100
#   Total number of iterations    :           35
#   Number of cells re-sampled    :            6
#   Total number of models        :         3700
#   Random seed value             :       125477
#   Pseudo-random sequence used
#   Starting models generated randomly
#
# ------------------------------------------------------------------------
#
#
#   start forward modeling iteration:            0
#   adding up the misfits   1071740.25
#   adding up the misfits   252300.703
#   adding up the misfits   296632.625
#   adding up the misfits   1610507.00
#   adding up the misfits   3723558.00
#   adding up the misfits   256403.594
#   adding up the misfits   34427252.0
#   adding up the misfits   508676.688
#   adding up the misfits   400181.438
#   adding up the misfits   1078527.75
#   adding up the misfits   832806.625
#   adding up the misfits   641345.312
#   adding up the misfits   446671.125
#   adding up the misfits   45725136.0
#   adding up the misfits   1111711.00
#   adding up the misfits   274298.344
#   adding up the misfits   5888257.50
#   adding up the misfits   392740.875
#   adding up the misfits   1224962.25
#   adding up the misfits   12241796.0
#   adding up the misfits   1621624.88
#   adding up the misfits   279030.875
#   adding up the misfits   1719754.25
#   adding up the misfits   365355.312
#   adding up the misfits   314112.844
#   adding up the misfits   83580360.0
#   adding up the misfits   489465.156
#   adding up the misfits   5191459.50
#   adding up the misfits   446239.875
#   adding up the misfits   19656216.0
#   adding up the misfits   634538.750
#   adding up the misfits   4813916.00
#   adding up the misfits   767823.062
#   adding up the misfits   399852.938
#   adding up the misfits   3221177.50
#   adding up the misfits   1043986.62
#   adding up the misfits   11615939.0
#   adding up the misfits   6341753.00
#   adding up the misfits   340314.594
#   adding up the misfits   906284.125
#   adding up the misfits   928743.000
#   adding up the misfits   563619.125
#   adding up the misfits   1023319.69
#   adding up the misfits   1191298.62
#   adding up the misfits   1535661.75
#   adding up the misfits   5264986.50
#   adding up the misfits   430451.969
#   adding up the misfits   326971.812
#   adding up the misfits   816473.000
#   adding up the misfits   1729261.38
#   adding up the misfits   5809729.50
#   adding up the misfits   311097.531
#   adding up the misfits   1416890.25
#   adding up the misfits   701515.188
#   adding up the misfits   260029.016
#   adding up the misfits   1085854.62
#   adding up the misfits   263545.594
#   adding up the misfits   1864821.38
#   adding up the misfits   253038.359
#   adding up the misfits   682744.188
#   adding up the misfits   380672.594
#   adding up the misfits   16518585.0
#   adding up the misfits   2262587.75
#   adding up the misfits   441713.938
#   adding up the misfits   682605.188
#   adding up the misfits   830681.000
#   adding up the misfits   313599.500
#   adding up the misfits   530358.188
#   adding up the misfits   326363.719
#   adding up the misfits   591693.125
#   adding up the misfits   2479583.50
#   adding up the misfits   2429380.50
#   adding up the misfits   270670.062
#   adding up the misfits   297768.875
#   adding up the misfits   481722.906
#   adding up the misfits   21553166.0
#   adding up the misfits   336468.344
#   adding up the misfits   277045440.
#   adding up the misfits   1116656.00
#   adding up the misfits   2481077.50
#   adding up the misfits   426310.375
#   adding up the misfits   4246329.50
#   adding up the misfits   584918.125
#   adding up the misfits   5906713.50
#   adding up the misfits   8434605.00
#   adding up the misfits   12125947.0
#   adding up the misfits   10643671.0
#   adding up the misfits   322152.531
#   adding up the misfits   2262465.00
#   adding up the misfits   422582.688
#   adding up the misfits   1334553.50
#   adding up the misfits   877379.875
#   adding up the misfits   1426981.38
#   adding up the misfits   41736720.0
#   adding up the misfits   490884.594
#   adding up the misfits   38860504.0
#   adding up the misfits   2200264.25
#   adding up the misfits   711689.500
#   adding up the misfits   2224544.25
#   adding up the misfits   276044.281
#   adding up the misfits   16568002.0
#   adding up the misfits   3382874.25
#   adding up the misfits   30026162.0
#   adding up the misfits   2002058.38
#   adding up the misfits   1310959.50
#   adding up the misfits   1845067.75
#   adding up the misfits   1448453.25
#   adding up the misfits   335541.000
#   adding up the misfits   651390.000
#   adding up the misfits   261615.328
#   adding up the misfits   7298970.00
#   adding up the misfits   385251.562
#   adding up the misfits   52914380.0
#   adding up the misfits   19712028.0
#   adding up the misfits   20815492.0
#   adding up the misfits   39778256.0
#   adding up the misfits   2920484.25
#   adding up the misfits   5329713.50
#   adding up the misfits   20639002.0
#   adding up the misfits   39961080.0
#   adding up the misfits   262363.938
#   adding up the misfits   313799.312
#   adding up the misfits   611753.562
#   adding up the misfits   262139.219
#   adding up the misfits   1920985.50
#   adding up the misfits   318401.531
#   adding up the misfits   1483055.25
#   adding up the misfits   368084.938
#   adding up the misfits   462788.625
#   adding up the misfits   20033420.0
#   adding up the misfits   603448.562
#   adding up the misfits   388055.938
#   adding up the misfits   607153.062
#   adding up the misfits   581009.625
#   adding up the misfits   1345697.50
#   adding up the misfits   273694.750
#   adding up the misfits   3034274.50
#   adding up the misfits   336449.250
#   adding up the misfits   2102370.50
#   adding up the misfits   38391220.0
#   adding up the misfits   1688563.25
#   adding up the misfits   506400.906
#   adding up the misfits   705361.000
#   adding up the misfits   885459.500
#   adding up the misfits   9255660.00
#   adding up the misfits   6828256.00
#   adding up the misfits   29467694.0
#   adding up the misfits   630196.875
#   adding up the misfits   2911061.75
#   adding up the misfits   1289832.12
#   adding up the misfits   593006.438
#   adding up the misfits   296122.062
#   adding up the misfits   436544.812
#   adding up the misfits   359068.531
#   adding up the misfits   519868.250
#   adding up the misfits   18398458.0
#   adding up the misfits   287136.562
#   adding up the misfits   804355.125
#   adding up the misfits   26560188.0
#   adding up the misfits   485905.156
#   adding up the misfits   1408373.25
#   adding up the misfits   717393.625
#   adding up the misfits   1303844.12
#   adding up the misfits   3632029.50
#   adding up the misfits   705856.312
#   adding up the misfits   4052873.00
#   adding up the misfits   1260663.62
#   adding up the misfits   262114.375
#   adding up the misfits   10492380.0
#   adding up the misfits   37431792.0
#   adding up the misfits   3364772.25
#   adding up the misfits   4571510.50
#   adding up the misfits   27344914.0
#   adding up the misfits   290138.812
#   adding up the misfits   574035.812
#   adding up the misfits   4175782.75
#   adding up the misfits   1635978.12
#   adding up the misfits   414014.531
#   adding up the misfits   354637.000
#   adding up the misfits   1510840.50
#   adding up the misfits   309286.500
#   adding up the misfits   568996.250
#   adding up the misfits   1265867.12
#   adding up the misfits   420133.875
#   adding up the misfits   5375910.00
#   adding up the misfits   33643800.0
#   adding up the misfits   1454443.25
#   adding up the misfits   4274743.50
#   adding up the misfits   11745766.0
#   adding up the misfits   526634.312
#   adding up the misfits   1237878.00
#   adding up the misfits   90821584.0
#   adding up the misfits   5722004.00
#   adding up the misfits   674725.125
#   adding up the misfits   2934943.00
#   adding up the misfits   377383.531
#   adding up the misfits   1591450.75
#   adding up the misfits   611530.625
#   adding up the misfits   6926032.00
#   adding up the misfits   624048.688
#   finished forward modeling
#   min/max cpu time for fwd on root node is    6.75299997E-03 /   6.75299997E-03
#
#   start forward modeling iteration:            1
#   adding up the misfits   275900.438
#   adding up the misfits   275642.344
#   adding up the misfits   256212.531
#   adding up the misfits   267734.000
#   adding up the misfits   293382.000
#   adding up the misfits   337269.906
#   adding up the misfits   304141.281
#   adding up the misfits   305662.219
#   adding up the misfits   307322.344
#   adding up the misfits   290078.156
#   adding up the misfits   318583.594
#   adding up the misfits   291422.344
#   adding up the misfits   251389.391
#   adding up the misfits   252306.469
#   adding up the misfits   270571.125
#   adding up the misfits   279532.312
#   adding up the misfits   314823.219
#   adding up the misfits   302936.188
#   adding up the misfits   275326.625
#   adding up the misfits   298076.781
#   adding up the misfits   252387.953
#   adding up the misfits   266360.375
#   adding up the misfits   353450.719
#   adding up the misfits   305831.656
#   adding up the misfits   296641.906
#   adding up the misfits   254612.453
#   adding up the misfits   253379.750
#   adding up the misfits   251004.734
#   adding up the misfits   269463.344
#   adding up the misfits   250477.406
#   adding up the misfits   248237.344
#   adding up the misfits   247598.062
#   adding up the misfits   280452.812
#   adding up the misfits   305664.938
#   adding up the misfits   282311.312
#   adding up the misfits   297409.375
#   adding up the misfits   259540.422
#   adding up the misfits   293603.031
#   adding up the misfits   393698.000
#   adding up the misfits   367588.875
#   adding up the misfits   320061.594
#   adding up the misfits   320505.500
#   adding up the misfits   304491.562
#   adding up the misfits   304334.906
#   adding up the misfits   274282.125
#   adding up the misfits   369551.688
#   adding up the misfits   254252.297
#   adding up the misfits   255520.969
#   adding up the misfits   375818.281
#   adding up the misfits   369970.156
#   adding up the misfits   262916.375
#   adding up the misfits   253685.625
#   adding up the misfits   256549.734
#   adding up the misfits   284634.250
#   adding up the misfits   254860.141
#   adding up the misfits   274296.000
#   adding up the misfits   400625.656
#   adding up the misfits   257862.938
#   adding up the misfits   399952.969
#   adding up the misfits   289457.312
#   adding up the misfits   322837.219
#   adding up the misfits   271889.438
#   adding up the misfits   320872.438
#   adding up the misfits   346632.344
#   adding up the misfits   263377.125
#   adding up the misfits   280144.156
#   adding up the misfits   253913.297
#   adding up the misfits   250647.859
#   adding up the misfits   277057.031
#   adding up the misfits   257839.203
#   adding up the misfits   257906.250
#   adding up the misfits   366366.375
#   adding up the misfits   338464.562
#   adding up the misfits   273538.281
#   adding up the misfits   337869.438
#   adding up the misfits   339318.062
#   adding up the misfits   341931.031
#   adding up the misfits   277750.469
#   adding up the misfits   311261.875
#   adding up the misfits   286179.000
#   adding up the misfits   306514.719
#   adding up the misfits   266854.469
#   adding up the misfits   264215.812
#   adding up the misfits   277767.531
#   adding up the misfits   256070.188
#   adding up the misfits   259030.141
#   adding up the misfits   264952.219
#   adding up the misfits   278116.344
#   adding up the misfits   273642.844
#   adding up the misfits   261444.500
#   adding up the misfits   293945.250
#   adding up the misfits   276791.094
#   adding up the misfits   271384.406
#   adding up the misfits   262050.391
#   adding up the misfits   317521.594
#   adding up the misfits   310750.406
#   adding up the misfits   270919.094
#   adding up the misfits   261686.578
#   adding up the misfits   266655.125
#   adding up the misfits   273174.750
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.05900001E-03 /   6.75299997E-03
#
#   start forward modeling iteration:            2
#   adding up the misfits   266167.844
#   adding up the misfits   267056.344
#   adding up the misfits   284957.969
#   adding up the misfits   252419.234
#   adding up the misfits   248214.406
#   adding up the misfits   251665.125
#   adding up the misfits   253890.156
#   adding up the misfits   276829.219
#   adding up the misfits   269069.312
#   adding up the misfits   253677.594
#   adding up the misfits   262598.062
#   adding up the misfits   275605.406
#   adding up the misfits   279856.094
#   adding up the misfits   260569.406
#   adding up the misfits   270322.188
#   adding up the misfits   266081.062
#   adding up the misfits   276586.750
#   adding up the misfits   250032.828
#   adding up the misfits   270574.750
#   adding up the misfits   275320.375
#   adding up the misfits   270693.750
#   adding up the misfits   270117.812
#   adding up the misfits   251528.734
#   adding up the misfits   255337.781
#   adding up the misfits   272723.938
#   adding up the misfits   249284.969
#   adding up the misfits   249486.969
#   adding up the misfits   247946.969
#   adding up the misfits   256731.812
#   adding up the misfits   267559.344
#   adding up the misfits   268028.875
#   adding up the misfits   249727.906
#   adding up the misfits   255706.578
#   adding up the misfits   271698.906
#   adding up the misfits   269275.812
#   adding up the misfits   261016.172
#   adding up the misfits   256753.578
#   adding up the misfits   289185.688
#   adding up the misfits   312476.469
#   adding up the misfits   329689.156
#   adding up the misfits   299767.094
#   adding up the misfits   304063.031
#   adding up the misfits   295822.562
#   adding up the misfits   261765.734
#   adding up the misfits   266284.688
#   adding up the misfits   270051.125
#   adding up the misfits   293129.062
#   adding up the misfits   281328.406
#   adding up the misfits   288361.562
#   adding up the misfits   271599.219
#   adding up the misfits   313016.750
#   adding up the misfits   293127.031
#   adding up the misfits   266499.062
#   adding up the misfits   265703.531
#   adding up the misfits   257483.609
#   adding up the misfits   251906.906
#   adding up the misfits   273618.906
#   adding up the misfits   286478.219
#   adding up the misfits   288512.250
#   adding up the misfits   262973.219
#   adding up the misfits   262275.719
#   adding up the misfits   274442.469
#   adding up the misfits   272081.062
#   adding up the misfits   283780.500
#   adding up the misfits   269771.781
#   adding up the misfits   269470.969
#   adding up the misfits   304068.938
#   adding up the misfits   286920.500
#   adding up the misfits   275618.625
#   adding up the misfits   259445.391
#   adding up the misfits   304943.531
#   adding up the misfits   295673.188
#   adding up the misfits   271613.031
#   adding up the misfits   249804.312
#   adding up the misfits   265829.656
#   adding up the misfits   286319.406
#   adding up the misfits   277516.750
#   adding up the misfits   261486.984
#   adding up the misfits   296450.344
#   adding up the misfits   294941.062
#   adding up the misfits   272596.156
#   adding up the misfits   259040.375
#   adding up the misfits   261426.734
#   adding up the misfits   251507.062
#   adding up the misfits   253359.312
#   adding up the misfits   273845.969
#   adding up the misfits   277891.969
#   adding up the misfits   293052.406
#   adding up the misfits   285765.531
#   adding up the misfits   258563.000
#   adding up the misfits   262760.906
#   adding up the misfits   261521.062
#   adding up the misfits   277452.719
#   adding up the misfits   302228.062
#   adding up the misfits   293942.906
#   adding up the misfits   254292.219
#   adding up the misfits   300794.156
#   adding up the misfits   264216.906
#   adding up the misfits   276738.812
#   adding up the misfits   279448.531
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#
#   start forward modeling iteration:            3
#   adding up the misfits   254583.984
#   adding up the misfits   254557.406
#   adding up the misfits   249773.891
#   adding up the misfits   249118.719
#   adding up the misfits   248101.812
#   adding up the misfits   258388.547
#   adding up the misfits   248973.250
#   adding up the misfits   250507.234
#   adding up the misfits   249816.094
#   adding up the misfits   254790.312
#   adding up the misfits   252374.875
#   adding up the misfits   256484.594
#   adding up the misfits   249002.750
#   adding up the misfits   251557.297
#   adding up the misfits   255940.156
#   adding up the misfits   255229.516
#   adding up the misfits   250240.812
#   adding up the misfits   258724.156
#   adding up the misfits   258591.656
#   adding up the misfits   255794.062
#   adding up the misfits   249861.625
#   adding up the misfits   264844.156
#   adding up the misfits   260899.812
#   adding up the misfits   264770.438
#   adding up the misfits   260898.484
#   adding up the misfits   263394.844
#   adding up the misfits   252539.953
#   adding up the misfits   260680.938
#   adding up the misfits   261097.859
#   adding up the misfits   265006.062
#   adding up the misfits   250774.312
#   adding up the misfits   252449.125
#   adding up the misfits   250445.391
#   adding up the misfits   249817.234
#   adding up the misfits   254874.578
#   adding up the misfits   252870.969
#   adding up the misfits   251073.484
#   adding up the misfits   248286.047
#   adding up the misfits   266575.281
#   adding up the misfits   255823.375
#   adding up the misfits   278412.625
#   adding up the misfits   279067.938
#   adding up the misfits   267264.625
#   adding up the misfits   264056.719
#   adding up the misfits   271659.781
#   adding up the misfits   264645.625
#   adding up the misfits   274680.625
#   adding up the misfits   284542.594
#   adding up the misfits   282183.812
#   adding up the misfits   259413.500
#   adding up the misfits   256483.156
#   adding up the misfits   250862.422
#   adding up the misfits   250958.328
#   adding up the misfits   264681.000
#   adding up the misfits   256500.531
#   adding up the misfits   253855.109
#   adding up the misfits   252541.266
#   adding up the misfits   254992.719
#   adding up the misfits   250113.234
#   adding up the misfits   252050.391
#   adding up the misfits   252471.109
#   adding up the misfits   249661.172
#   adding up the misfits   250056.406
#   adding up the misfits   262129.531
#   adding up the misfits   257219.062
#   adding up the misfits   254385.891
#   adding up the misfits   259090.891
#   adding up the misfits   262540.844
#   adding up the misfits   248030.875
#   adding up the misfits   260060.859
#   adding up the misfits   247722.766
#   adding up the misfits   263088.156
#   adding up the misfits   264145.000
#   adding up the misfits   263901.156
#   adding up the misfits   259464.281
#   adding up the misfits   260591.797
#   adding up the misfits   259182.141
#   adding up the misfits   271365.656
#   adding up the misfits   268215.812
#   adding up the misfits   259178.078
#   adding up the misfits   260488.125
#   adding up the misfits   249757.359
#   adding up the misfits   253744.516
#   adding up the misfits   256234.219
#   adding up the misfits   263321.656
#   adding up the misfits   260829.141
#   adding up the misfits   255645.156
#   adding up the misfits   258029.000
#   adding up the misfits   258014.812
#   adding up the misfits   252039.797
#   adding up the misfits   251164.047
#   adding up the misfits   253500.984
#   adding up the misfits   253661.359
#   adding up the misfits   249450.594
#   adding up the misfits   252997.031
#   adding up the misfits   249885.219
#   adding up the misfits   248448.328
#   adding up the misfits   249013.281
#   adding up the misfits   248036.438
#   adding up the misfits   252756.375
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#   start forward modeling iteration:            4
#   adding up the misfits   251957.844
#   adding up the misfits   248527.625
#   adding up the misfits   249253.375
#   adding up the misfits   250185.094
#   adding up the misfits   248260.781
#   adding up the misfits   248448.734
#   adding up the misfits   249936.594
#   adding up the misfits   248067.203
#   adding up the misfits   248149.047
#   adding up the misfits   248086.359
#   adding up the misfits   248930.703
#   adding up the misfits   247985.453
#   adding up the misfits   249243.422
#   adding up the misfits   251061.766
#   adding up the misfits   249288.922
#   adding up the misfits   248009.016
#   adding up the misfits   250362.609
#   adding up the misfits   248884.047
#   adding up the misfits   256223.500
#   adding up the misfits   253257.109
#   adding up the misfits   250456.922
#   adding up the misfits   251194.688
#   adding up the misfits   260940.188
#   adding up the misfits   249935.969
#   adding up the misfits   253932.406
#   adding up the misfits   248858.781
#   adding up the misfits   252725.141
#   adding up the misfits   260722.672
#   adding up the misfits   250233.500
#   adding up the misfits   251998.234
#   adding up the misfits   251773.531
#   adding up the misfits   258649.969
#   adding up the misfits   260508.625
#   adding up the misfits   258605.516
#   adding up the misfits   250137.031
#   adding up the misfits   253199.500
#   adding up the misfits   254233.766
#   adding up the misfits   253733.078
#   adding up the misfits   253127.062
#   adding up the misfits   248532.719
#   adding up the misfits   251609.688
#   adding up the misfits   251229.984
#   adding up the misfits   250315.531
#   adding up the misfits   250192.547
#   adding up the misfits   251827.344
#   adding up the misfits   250459.141
#   adding up the misfits   252330.109
#   adding up the misfits   252521.750
#   adding up the misfits   250686.484
#   adding up the misfits   251412.719
#   adding up the misfits   252279.688
#   adding up the misfits   255194.344
#   adding up the misfits   249837.500
#   adding up the misfits   249685.406
#   adding up the misfits   255696.328
#   adding up the misfits   254198.406
#   adding up the misfits   249877.062
#   adding up the misfits   254000.781
#   adding up the misfits   251172.156
#   adding up the misfits   256556.578
#   adding up the misfits   258791.906
#   adding up the misfits   251253.266
#   adding up the misfits   248573.797
#   adding up the misfits   247702.938
#   adding up the misfits   248162.328
#   adding up the misfits   248521.266
#   adding up the misfits   249931.750
#   adding up the misfits   248474.562
#   adding up the misfits   252922.391
#   adding up the misfits   249937.641
#   adding up the misfits   252914.719
#   adding up the misfits   249405.453
#   adding up the misfits   252364.156
#   adding up the misfits   250853.797
#   adding up the misfits   254300.344
#   adding up the misfits   252839.391
#   adding up the misfits   253241.531
#   adding up the misfits   257833.750
#   adding up the misfits   253685.078
#   adding up the misfits   249370.281
#   adding up the misfits   250112.719
#   adding up the misfits   254984.859
#   adding up the misfits   252309.672
#   adding up the misfits   250843.516
#   adding up the misfits   248125.266
#   adding up the misfits   253721.438
#   adding up the misfits   252291.062
#   adding up the misfits   250582.375
#   adding up the misfits   250147.234
#   adding up the misfits   251654.938
#   adding up the misfits   251398.438
#   adding up the misfits   249318.344
#   adding up the misfits   251453.953
#   adding up the misfits   247647.594
#   adding up the misfits   257339.016
#   adding up the misfits   253627.844
#   adding up the misfits   257689.062
#   adding up the misfits   248671.625
#   adding up the misfits   250841.109
#   adding up the misfits   256022.641
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#
#   start forward modeling iteration:            5
#   adding up the misfits   248041.766
#   adding up the misfits   247783.062
#   adding up the misfits   248845.500
#   adding up the misfits   249300.125
#   adding up the misfits   247466.891
#   adding up the misfits   248218.672
#   adding up the misfits   248865.297
#   adding up the misfits   249011.750
#   adding up the misfits   248952.078
#   adding up the misfits   249385.844
#   adding up the misfits   248132.438
#   adding up the misfits   249848.875
#   adding up the misfits   249349.688
#   adding up the misfits   248031.875
#   adding up the misfits   247605.750
#   adding up the misfits   249045.641
#   adding up the misfits   248225.422
#   adding up the misfits   250024.484
#   adding up the misfits   252534.969
#   adding up the misfits   252953.062
#   adding up the misfits   252221.406
#   adding up the misfits   249897.516
#   adding up the misfits   247891.516
#   adding up the misfits   249610.438
#   adding up the misfits   248402.719
#   adding up the misfits   252143.047
#   adding up the misfits   250102.203
#   adding up the misfits   249329.391
#   adding up the misfits   248444.156
#   adding up the misfits   250307.812
#   adding up the misfits   251974.047
#   adding up the misfits   250939.656
#   adding up the misfits   248944.922
#   adding up the misfits   248691.672
#   adding up the misfits   248751.531
#   adding up the misfits   252355.359
#   adding up the misfits   253087.750
#   adding up the misfits   247487.047
#   adding up the misfits   249283.188
#   adding up the misfits   253818.906
#   adding up the misfits   253244.047
#   adding up the misfits   251761.625
#   adding up the misfits   247862.266
#   adding up the misfits   248594.578
#   adding up the misfits   250465.531
#   adding up the misfits   250929.812
#   adding up the misfits   257788.984
#   adding up the misfits   248718.078
#   adding up the misfits   252655.547
#   adding up the misfits   253407.359
#   adding up the misfits   257785.578
#   adding up the misfits   248946.078
#   adding up the misfits   249144.609
#   adding up the misfits   250261.312
#   adding up the misfits   248228.906
#   adding up the misfits   248857.969
#   adding up the misfits   248775.797
#   adding up the misfits   248256.969
#   adding up the misfits   251456.625
#   adding up the misfits   253370.953
#   adding up the misfits   251153.750
#   adding up the misfits   253426.188
#   adding up the misfits   253293.156
#   adding up the misfits   251409.344
#   adding up the misfits   248093.516
#   adding up the misfits   251543.422
#   adding up the misfits   250938.750
#   adding up the misfits   248428.875
#   adding up the misfits   247918.797
#   adding up the misfits   248773.453
#   adding up the misfits   248493.953
#   adding up the misfits   249147.250
#   adding up the misfits   248746.125
#   adding up the misfits   247919.297
#   adding up the misfits   248526.609
#   adding up the misfits   248928.156
#   adding up the misfits   249357.125
#   adding up the misfits   248837.750
#   adding up the misfits   251154.312
#   adding up the misfits   248585.969
#   adding up the misfits   248532.984
#   adding up the misfits   248026.016
#   adding up the misfits   248175.641
#   adding up the misfits   248894.438
#   adding up the misfits   247898.875
#   adding up the misfits   250723.391
#   adding up the misfits   249257.656
#   adding up the misfits   248706.953
#   adding up the misfits   247909.250
#   adding up the misfits   247724.297
#   adding up the misfits   247779.172
#   adding up the misfits   248438.406
#   adding up the misfits   248740.484
#   adding up the misfits   247900.969
#   adding up the misfits   248730.438
#   adding up the misfits   249637.828
#   adding up the misfits   250879.234
#   adding up the misfits   251159.141
#   adding up the misfits   252116.281
#   adding up the misfits   251764.516
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#
#   start forward modeling iteration:            6
#   adding up the misfits   248518.203
#   adding up the misfits   248102.141
#   adding up the misfits   249090.672
#   adding up the misfits   247938.734
#   adding up the misfits   247620.172
#   adding up the misfits   248420.703
#   adding up the misfits   248458.000
#   adding up the misfits   248308.188
#   adding up the misfits   248222.281
#   adding up the misfits   248733.984
#   adding up the misfits   248477.641
#   adding up the misfits   248824.484
#   adding up the misfits   248426.062
#   adding up the misfits   248392.562
#   adding up the misfits   248304.406
#   adding up the misfits   248794.828
#   adding up the misfits   247739.641
#   adding up the misfits   266796.125
#   adding up the misfits   265567.750
#   adding up the misfits   250397.594
#   adding up the misfits   255885.781
#   adding up the misfits   260455.344
#   adding up the misfits   262406.906
#   adding up the misfits   251175.734
#   adding up the misfits   255540.844
#   adding up the misfits   249974.688
#   adding up the misfits   273196.469
#   adding up the misfits   254354.328
#   adding up the misfits   257285.156
#   adding up the misfits   254514.734
#   adding up the misfits   249344.766
#   adding up the misfits   250731.188
#   adding up the misfits   267393.219
#   adding up the misfits   249040.250
#   adding up the misfits   247812.641
#   adding up the misfits   247576.500
#   adding up the misfits   247827.625
#   adding up the misfits   247613.375
#   adding up the misfits   247816.656
#   adding up the misfits   247951.312
#   adding up the misfits   247517.844
#   adding up the misfits   248047.266
#   adding up the misfits   248331.641
#   adding up the misfits   247612.562
#   adding up the misfits   247945.594
#   adding up the misfits   247899.000
#   adding up the misfits   248427.562
#   adding up the misfits   248270.094
#   adding up the misfits   247600.781
#   adding up the misfits   247590.312
#   adding up the misfits   247472.906
#   adding up the misfits   247978.344
#   adding up the misfits   247841.250
#   adding up the misfits   247630.562
#   adding up the misfits   247732.844
#   adding up the misfits   247680.281
#   adding up the misfits   247468.531
#   adding up the misfits   247479.312
#   adding up the misfits   248502.594
#   adding up the misfits   247804.594
#   adding up the misfits   247997.734
#   adding up the misfits   247749.172
#   adding up the misfits   247785.109
#   adding up the misfits   248516.594
#   adding up the misfits   248914.594
#   adding up the misfits   248377.203
#   adding up the misfits   248269.094
#   adding up the misfits   249056.156
#   adding up the misfits   247767.453
#   adding up the misfits   247763.688
#   adding up the misfits   248067.172
#   adding up the misfits   250112.453
#   adding up the misfits   249128.922
#   adding up the misfits   249142.141
#   adding up the misfits   248049.109
#   adding up the misfits   248326.172
#   adding up the misfits   250041.703
#   adding up the misfits   248881.562
#   adding up the misfits   248536.328
#   adding up the misfits   248473.000
#   adding up the misfits   250022.828
#   adding up the misfits   249727.734
#   adding up the misfits   250350.578
#   adding up the misfits   249086.844
#   adding up the misfits   248392.938
#   adding up the misfits   247466.203
#   adding up the misfits   248533.984
#   adding up the misfits   248115.688
#   adding up the misfits   250756.531
#   adding up the misfits   251062.438
#   adding up the misfits   250143.875
#   adding up the misfits   249045.547
#   adding up the misfits   251339.109
#   adding up the misfits   250090.734
#   adding up the misfits   247420.797
#   adding up the misfits   257366.125
#   adding up the misfits   250080.984
#   adding up the misfits   247556.328
#   adding up the misfits   248296.625
#   adding up the misfits   249234.500
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#
#   start forward modeling iteration:            7
#   adding up the misfits   248244.469
#   adding up the misfits   248453.562
#   adding up the misfits   247739.547
#   adding up the misfits   248101.906
#   adding up the misfits   247577.594
#   adding up the misfits   247763.156
#   adding up the misfits   247880.438
#   adding up the misfits   247701.969
#   adding up the misfits   247405.938
#   adding up the misfits   248242.203
#   adding up the misfits   249390.625
#   adding up the misfits   247513.047
#   adding up the misfits   247593.172
#   adding up the misfits   247502.984
#   adding up the misfits   248616.844
#   adding up the misfits   247864.688
#   adding up the misfits   247950.688
#   adding up the misfits   250831.531
#   adding up the misfits   250039.047
#   adding up the misfits   250161.250
#   adding up the misfits   248632.469
#   adding up the misfits   249296.266
#   adding up the misfits   251287.891
#   adding up the misfits   249893.844
#   adding up the misfits   248995.047
#   adding up the misfits   249473.016
#   adding up the misfits   252642.609
#   adding up the misfits   250337.328
#   adding up the misfits   248829.922
#   adding up the misfits   250131.281
#   adding up the misfits   251941.344
#   adding up the misfits   251411.219
#   adding up the misfits   251423.891
#   adding up the misfits   250053.859
#   adding up the misfits   247544.797
#   adding up the misfits   248225.938
#   adding up the misfits   247982.141
#   adding up the misfits   248325.062
#   adding up the misfits   248136.719
#   adding up the misfits   248431.281
#   adding up the misfits   248481.000
#   adding up the misfits   247938.234
#   adding up the misfits   247746.484
#   adding up the misfits   248023.031
#   adding up the misfits   247477.719
#   adding up the misfits   248211.047
#   adding up the misfits   247462.859
#   adding up the misfits   247550.719
#   adding up the misfits   247848.531
#   adding up the misfits   247912.531
#   adding up the misfits   247861.859
#   adding up the misfits   248147.906
#   adding up the misfits   247634.172
#   adding up the misfits   248800.281
#   adding up the misfits   248197.844
#   adding up the misfits   248636.953
#   adding up the misfits   247706.359
#   adding up the misfits   247801.219
#   adding up the misfits   248449.859
#   adding up the misfits   248506.828
#   adding up the misfits   247686.641
#   adding up the misfits   248593.531
#   adding up the misfits   248645.922
#   adding up the misfits   248218.188
#   adding up the misfits   247922.078
#   adding up the misfits   248206.734
#   adding up the misfits   248129.234
#   adding up the misfits   248446.359
#   adding up the misfits   248390.594
#   adding up the misfits   248284.344
#   adding up the misfits   248228.766
#   adding up the misfits   247889.266
#   adding up the misfits   247533.047
#   adding up the misfits   247952.781
#   adding up the misfits   247839.578
#   adding up the misfits   247886.219
#   adding up the misfits   247821.891
#   adding up the misfits   248373.875
#   adding up the misfits   247891.453
#   adding up the misfits   247652.391
#   adding up the misfits   247809.922
#   adding up the misfits   247841.406
#   adding up the misfits   247984.047
#   adding up the misfits   248020.484
#   adding up the misfits   248449.031
#   adding up the misfits   247986.203
#   adding up the misfits   250891.359
#   adding up the misfits   251965.125
#   adding up the misfits   249650.953
#   adding up the misfits   248255.266
#   adding up the misfits   247763.062
#   adding up the misfits   250350.125
#   adding up the misfits   248456.922
#   adding up the misfits   247691.719
#   adding up the misfits   247528.266
#   adding up the misfits   248427.438
#   adding up the misfits   248174.984
#   adding up the misfits   247525.094
#   adding up the misfits   248661.094
#   adding up the misfits   249204.891
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#   start forward modeling iteration:            8
#   adding up the misfits   248919.484
#   adding up the misfits   247893.781
#   adding up the misfits   247946.062
#   adding up the misfits   247888.781
#   adding up the misfits   247548.688
#   adding up the misfits   247802.297
#   adding up the misfits   248765.562
#   adding up the misfits   249161.938
#   adding up the misfits   247593.391
#   adding up the misfits   248421.109
#   adding up the misfits   247954.109
#   adding up the misfits   247434.031
#   adding up the misfits   247612.375
#   adding up the misfits   247599.469
#   adding up the misfits   247445.422
#   adding up the misfits   247870.594
#   adding up the misfits   247507.234
#   adding up the misfits   247597.469
#   adding up the misfits   247622.047
#   adding up the misfits   248008.688
#   adding up the misfits   248005.562
#   adding up the misfits   247935.281
#   adding up the misfits   247823.500
#   adding up the misfits   248084.031
#   adding up the misfits   248486.359
#   adding up the misfits   247973.062
#   adding up the misfits   248105.750
#   adding up the misfits   249263.516
#   adding up the misfits   248310.422
#   adding up the misfits   248044.797
#   adding up the misfits   247604.953
#   adding up the misfits   247822.469
#   adding up the misfits   247947.359
#   adding up the misfits   247855.719
#   adding up the misfits   247478.797
#   adding up the misfits   248071.781
#   adding up the misfits   247902.188
#   adding up the misfits   247539.281
#   adding up the misfits   247590.453
#   adding up the misfits   247702.406
#   adding up the misfits   248022.312
#   adding up the misfits   247948.500
#   adding up the misfits   247826.734
#   adding up the misfits   247833.500
#   adding up the misfits   247677.641
#   adding up the misfits   247653.266
#   adding up the misfits   248065.531
#   adding up the misfits   247517.250
#   adding up the misfits   247709.312
#   adding up the misfits   247796.625
#   adding up the misfits   248232.547
#   adding up the misfits   247919.719
#   adding up the misfits   248177.672
#   adding up the misfits   248301.375
#   adding up the misfits   247723.469
#   adding up the misfits   248299.562
#   adding up the misfits   247577.422
#   adding up the misfits   248262.812
#   adding up the misfits   248232.438
#   adding up the misfits   247824.312
#   adding up the misfits   247750.500
#   adding up the misfits   247690.000
#   adding up the misfits   247623.016
#   adding up the misfits   248017.531
#   adding up the misfits   248154.172
#   adding up the misfits   247504.875
#   adding up the misfits   248108.750
#   adding up the misfits   247962.641
#   adding up the misfits   247603.594
#   adding up the misfits   247480.062
#   adding up the misfits   247689.531
#   adding up the misfits   247643.828
#   adding up the misfits   247667.703
#   adding up the misfits   247605.641
#   adding up the misfits   247567.062
#   adding up the misfits   247467.234
#   adding up the misfits   247475.969
#   adding up the misfits   247620.406
#   adding up the misfits   248001.578
#   adding up the misfits   247787.250
#   adding up the misfits   247868.500
#   adding up the misfits   247894.672
#   adding up the misfits   247783.578
#   adding up the misfits   247584.516
#   adding up the misfits   247695.422
#   adding up the misfits   247743.562
#   adding up the misfits   247589.719
#   adding up the misfits   247462.250
#   adding up the misfits   247473.234
#   adding up the misfits   247740.938
#   adding up the misfits   247865.422
#   adding up the misfits   247584.000
#   adding up the misfits   247512.234
#   adding up the misfits   247597.891
#   adding up the misfits   247863.500
#   adding up the misfits   247511.422
#   adding up the misfits   247678.656
#   adding up the misfits   247506.797
#   adding up the misfits   247630.875
#   adding up the misfits   247856.109
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#
#   start forward modeling iteration:            9
#   adding up the misfits   247757.656
#   adding up the misfits   247453.625
#   adding up the misfits   247610.734
#   adding up the misfits   247510.484
#   adding up the misfits   248106.094
#   adding up the misfits   247963.047
#   adding up the misfits   248318.484
#   adding up the misfits   248278.672
#   adding up the misfits   247910.812
#   adding up the misfits   247896.328
#   adding up the misfits   247929.094
#   adding up the misfits   247407.984
#   adding up the misfits   247459.375
#   adding up the misfits   248269.422
#   adding up the misfits   247457.109
#   adding up the misfits   247867.734
#   adding up the misfits   247455.828
#   adding up the misfits   247442.281
#   adding up the misfits   247414.281
#   adding up the misfits   247621.406
#   adding up the misfits   247486.891
#   adding up the misfits   247627.734
#   adding up the misfits   247594.750
#   adding up the misfits   247632.656
#   adding up the misfits   247782.172
#   adding up the misfits   247460.953
#   adding up the misfits   247403.828
#   adding up the misfits   247671.703
#   adding up the misfits   247602.750
#   adding up the misfits   247540.484
#   adding up the misfits   247412.531
#   adding up the misfits   247438.359
#   adding up the misfits   247447.938
#   adding up the misfits   247641.500
#   adding up the misfits   247467.078
#   adding up the misfits   247491.531
#   adding up the misfits   247493.797
#   adding up the misfits   247636.609
#   adding up the misfits   247495.062
#   adding up the misfits   247392.672
#   adding up the misfits   248018.344
#   adding up the misfits   247497.453
#   adding up the misfits   248132.594
#   adding up the misfits   248129.797
#   adding up the misfits   248019.047
#   adding up the misfits   247946.594
#   adding up the misfits   247785.516
#   adding up the misfits   247551.234
# ...
#   adding up the misfits   247350.125
#   adding up the misfits   247351.844
#   adding up the misfits   247350.203
#   adding up the misfits   247350.328
#   adding up the misfits   247350.062
#   adding up the misfits   247351.109
#   adding up the misfits   247352.406
#   adding up the misfits   247352.953
#   adding up the misfits   247353.562
#   adding up the misfits   247353.234
#   adding up the misfits   247353.969
#   adding up the misfits   247351.750
#   adding up the misfits   247352.578
#   adding up the misfits   247351.000
#   adding up the misfits   247350.203
#   adding up the misfits   247350.156
#   adding up the misfits   247350.781
#   adding up the misfits   247350.391
#   adding up the misfits   247350.094
#   adding up the misfits   247350.156
#   adding up the misfits   247350.781
#   adding up the misfits   247350.141
#   adding up the misfits   247350.891
#   adding up the misfits   247350.828
#   adding up the misfits   247350.859
#   adding up the misfits   247350.719
#   adding up the misfits   247350.062
#   adding up the misfits   247350.859
#   adding up the misfits   247350.500
#   adding up the misfits   247350.812
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#
#   start forward modeling iteration:           33
#   adding up the misfits   247350.047
#   adding up the misfits   247350.078
#   adding up the misfits   247350.766
#   adding up the misfits   247350.797
#   adding up the misfits   247350.766
#   adding up the misfits   247350.125
#   adding up the misfits   247350.344
#   adding up the misfits   247351.188
#   adding up the misfits   247350.547
#   adding up the misfits   247350.156
#   adding up the misfits   247350.188
#   adding up the misfits   247350.766
#   adding up the misfits   247352.031
#   adding up the misfits   247351.656
#   adding up the misfits   247351.500
#   adding up the misfits   247351.453
#   adding up the misfits   247350.812
#   adding up the misfits   247350.641
#   adding up the misfits   247350.094
#   adding up the misfits   247350.219
#   adding up the misfits   247350.125
#   adding up the misfits   247351.406
#   adding up the misfits   247350.250
#   adding up the misfits   247350.484
#   adding up the misfits   247350.812
#   adding up the misfits   247350.844
#   adding up the misfits   247350.000
#   adding up the misfits   247350.156
#   adding up the misfits   247350.531
#   adding up the misfits   247350.094
#   adding up the misfits   247350.250
#   adding up the misfits   247350.422
#   adding up the misfits   247353.484
#   adding up the misfits   247355.203
#   adding up the misfits   247350.750
#   adding up the misfits   247350.453
#   adding up the misfits   247350.188
#   adding up the misfits   247350.250
#   adding up the misfits   247350.266
#   adding up the misfits   247350.734
#   adding up the misfits   247350.469
#   adding up the misfits   247351.109
#   adding up the misfits   247350.953
#   adding up the misfits   247350.938
#   adding up the misfits   247350.984
#   adding up the misfits   247351.734
#   adding up the misfits   247352.422
#   adding up the misfits   247354.094
#   adding up the misfits   247353.188
#   adding up the misfits   247353.656
#   adding up the misfits   247354.344
#   adding up the misfits   247350.719
#   adding up the misfits   247350.156
#   adding up the misfits   247350.125
#   adding up the misfits   247351.047
#   adding up the misfits   247351.172
#   adding up the misfits   247350.453
#   adding up the misfits   247350.188
#   adding up the misfits   247351.188
#   adding up the misfits   247351.438
#   adding up the misfits   247350.875
#   adding up the misfits   247350.844
#   adding up the misfits   247351.125
#   adding up the misfits   247350.172
#   adding up the misfits   247350.125
#   adding up the misfits   247350.672
#   adding up the misfits   247351.016
#   adding up the misfits   247350.625
#   adding up the misfits   247350.344
#   adding up the misfits   247350.422
#   adding up the misfits   247350.250
#   adding up the misfits   247350.312
#   adding up the misfits   247350.594
#   adding up the misfits   247350.438
#   adding up the misfits   247350.609
#   adding up the misfits   247350.562
#   adding up the misfits   247352.688
#   adding up the misfits   247351.891
#   adding up the misfits   247352.000
#   adding up the misfits   247351.766
#   adding up the misfits   247351.234
#   adding up the misfits   247352.484
#   adding up the misfits   247352.609
#   adding up the misfits   247351.453
#   adding up the misfits   247350.766
#   adding up the misfits   247350.625
#   adding up the misfits   247350.609
#   adding up the misfits   247351.172
#   adding up the misfits   247350.250
#   adding up the misfits   247350.250
#   adding up the misfits   247350.547
#   adding up the misfits   247351.281
#   adding up the misfits   247350.125
#   adding up the misfits   247350.047
#   adding up the misfits   247350.250
#   adding up the misfits   247350.219
#   adding up the misfits   247350.953
#   adding up the misfits   247350.125
#   adding up the misfits   247350.094
#   adding up the misfits   247350.234
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#   start forward modeling iteration:           34
#   adding up the misfits   247350.344
#   adding up the misfits   247350.156
#   adding up the misfits   247350.891
#   adding up the misfits   247352.219
#   adding up the misfits   247351.078
#   adding up the misfits   247350.562
#   adding up the misfits   247350.359
#   adding up the misfits   247350.047
#   adding up the misfits   247350.516
#   adding up the misfits   247350.125
#   adding up the misfits   247350.672
#   adding up the misfits   247350.562
#   adding up the misfits   247350.125
#   adding up the misfits   247350.094
#   adding up the misfits   247350.766
#   adding up the misfits   247350.516
#   adding up the misfits   247350.609
#   adding up the misfits   247350.391
#   adding up the misfits   247350.781
#   adding up the misfits   247352.609
#   adding up the misfits   247351.812
#   adding up the misfits   247350.312
#   adding up the misfits   247350.859
#   adding up the misfits   247355.109
#   adding up the misfits   247354.609
#   adding up the misfits   247355.922
#   adding up the misfits   247350.141
#   adding up the misfits   247351.516
#   adding up the misfits   247351.281
#   adding up the misfits   247350.859
#   adding up the misfits   247351.375
#   adding up the misfits   247350.250
#   adding up the misfits   247350.438
#   adding up the misfits   247351.281
#   adding up the misfits   247350.109
#   adding up the misfits   247350.109
#   adding up the misfits   247350.281
#   adding up the misfits   247350.328
#   adding up the misfits   247350.250
#   adding up the misfits   247350.969
#   adding up the misfits   247350.625
#   adding up the misfits   247350.438
#   adding up the misfits   247350.281
#   adding up the misfits   247350.516
#   adding up the misfits   247350.844
#   adding up the misfits   247350.391
#   adding up the misfits   247350.141
#   adding up the misfits   247351.062
#   adding up the misfits   247350.641
#   adding up the misfits   247350.125
#   adding up the misfits   247350.281
#   adding up the misfits   247350.141
#   adding up the misfits   247350.219
#   adding up the misfits   247350.125
#   adding up the misfits   247350.219
#   adding up the misfits   247350.141
#   adding up the misfits   247350.094
#   adding up the misfits   247350.078
#   adding up the misfits   247350.016
#   adding up the misfits   247350.453
#   adding up the misfits   247350.906
#   adding up the misfits   247350.969
#   adding up the misfits   247351.250
#   adding up the misfits   247351.141
#   adding up the misfits   247350.125
#   adding up the misfits   247350.625
#   adding up the misfits   247350.688
#   adding up the misfits   247350.375
#   adding up the misfits   247350.062
#   adding up the misfits   247350.328
#   adding up the misfits   247350.094
#   adding up the misfits   247350.094
#   adding up the misfits   247350.062
#   adding up the misfits   247350.219
#   adding up the misfits   247350.812
#   adding up the misfits   247350.828
#   adding up the misfits   247350.672
#   adding up the misfits   247350.906
#   adding up the misfits   247350.453
#   adding up the misfits   247350.828
#   adding up the misfits   247350.203
#   adding up the misfits   247350.203
#   adding up the misfits   247350.094
#   adding up the misfits   247350.031
#   adding up the misfits   247350.250
#   adding up the misfits   247350.734
#   adding up the misfits   247350.062
#   adding up the misfits   247351.406
#   adding up the misfits   247351.359
#   adding up the misfits   247350.547
#   adding up the misfits   247350.891
#   adding up the misfits   247350.969
#   adding up the misfits   247351.203
#   adding up the misfits   247350.953
#   adding up the misfits   247350.547
#   adding up the misfits   247350.500
#   adding up the misfits   247350.641
#   adding up the misfits   247350.219
#   adding up the misfits   247351.562
#   adding up the misfits   247351.297
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#
#   start forward modeling iteration:           35
#   adding up the misfits   247350.062
#   adding up the misfits   247350.188
#   adding up the misfits   247350.078
#   adding up the misfits   247350.312
#   adding up the misfits   247350.125
#   adding up the misfits   247350.562
#   adding up the misfits   247350.266
#   adding up the misfits   247350.141
#   adding up the misfits   247350.672
#   adding up the misfits   247350.484
#   adding up the misfits   247351.672
#   adding up the misfits   247351.516
#   adding up the misfits   247351.703
#   adding up the misfits   247351.594
#   adding up the misfits   247350.344
#   adding up the misfits   247350.531
#   adding up the misfits   247351.812
#   adding up the misfits   247350.109
#   adding up the misfits   247350.141
#   adding up the misfits   247350.281
#   adding up the misfits   247350.109
#   adding up the misfits   247350.125
#   adding up the misfits   247350.078
#   adding up the misfits   247350.062
#   adding up the misfits   247350.062
#   adding up the misfits   247350.156
#   adding up the misfits   247350.031
#   adding up the misfits   247350.141
#   adding up the misfits   247350.516
#   adding up the misfits   247350.500
#   adding up the misfits   247350.516
#   adding up the misfits   247350.469
#   adding up the misfits   247350.031
#   adding up the misfits   247350.547
#   adding up the misfits   247350.094
#   adding up the misfits   247350.609
#   adding up the misfits   247350.562
#   adding up the misfits   247350.469
#   adding up the misfits   247351.109
#   adding up the misfits   247351.766
#   adding up the misfits   247351.891
#   adding up the misfits   247352.844
#   adding up the misfits   247352.844
#   adding up the misfits   247354.531
#   adding up the misfits   247353.719
#   adding up the misfits   247353.125
#   adding up the misfits   247353.266
#   adding up the misfits   247351.703
#   adding up the misfits   247352.062
#   adding up the misfits   247351.125
#   adding up the misfits   247350.188
#   adding up the misfits   247350.031
#   adding up the misfits   247350.047
#   adding up the misfits   247350.125
#   adding up the misfits   247350.375
#   adding up the misfits   247350.547
#   adding up the misfits   247350.438
#   adding up the misfits   247350.953
#   adding up the misfits   247350.391
#   adding up the misfits   247350.188
#   adding up the misfits   247350.453
#   adding up the misfits   247350.641
#   adding up the misfits   247350.188
#   adding up the misfits   247350.172
#   adding up the misfits   247350.781
#   adding up the misfits   247350.234
#   adding up the misfits   247350.453
#   adding up the misfits   247350.578
#   adding up the misfits   247350.625
#   adding up the misfits   247350.625
#   adding up the misfits   247351.750
#   adding up the misfits   247350.703
#   adding up the misfits   247352.109
#   adding up the misfits   247353.297
#   adding up the misfits   247356.125
#   adding up the misfits   247350.172
#   adding up the misfits   247351.766
#   adding up the misfits   247351.500
#   adding up the misfits   247354.500
#   adding up the misfits   247352.078
#   adding up the misfits   247354.859
#   adding up the misfits   247350.578
#   adding up the misfits   247354.547
#   adding up the misfits   247354.594
#   adding up the misfits   247350.172
#   adding up the misfits   247350.328
#   adding up the misfits   247350.109
#   adding up the misfits   247350.406
#   adding up the misfits   247350.266
#   adding up the misfits   247350.078
#   adding up the misfits   247350.281
#   adding up the misfits   247350.344
#   adding up the misfits   247350.250
#   adding up the misfits   247350.047
#   adding up the misfits   247350.062
#   adding up the misfits   247350.484
#   adding up the misfits   247350.531
#   adding up the misfits   247351.609
#   adding up the misfits   247351.375
#   adding up the misfits   247351.094
#   finished forward modeling
#   min/max cpu time for fwd on root node is    3.01199988E-03 /   6.75299997E-03
#
#
#
#  Performance statistics
#
#  Total number of full dlist evaluations         210
#  Total number of partial dlist updates        13790
#  Lowest misfit found                      247350.000
#  Average misfit over all models           247350.938
#  Index of lowest misfit model                  3427
#
#  Total cpu time spent partially updating dlist             0.387011081
#  Total cpu time spent evaluating dlist                 1.32750003E-02
#  Total cpu time spent finding Voronoi intersections   0.500776112
#  Total cpu time spent calculating random deviates      1.23369973E-02
#  Total cpu time resetting random walks                 1.98999987E-04
#  Total cpu time for ordering misfits                   5.42199938E-03
#  Total elapsed wall time for fwd                      0.175408840
#  Total cpu time for NA-algorithm (without forward)    0.942302942
#  Total cpu time for forward modeling                  0.139477998
#  Minimum cpu time spent forward modelling               3.01199988E-03
#  Maximum cpu time spent forward modelling               6.75299997E-03
#  Total elapsed time for entire NA                      1.2375280857086182
#
#  ---
#  Mistfit best overall =    247350.000
#  for model:
#  Na2    =    1.20729278E-03
#  Ro_p   =    357.504883
#  ThetaA =    1.46698511
#  ThetaO =    6.79187775E-02
#  -------------------
#   Total length of header in (nad) direct  access model file =           65
#
#   Writing direct access file...
#
#
#   Files created:
#
#   na.nad : Direct access file containing ensemble of models
#   na.sum : Short summary file of progress
#   na.det : Full details of progress
#  Program nad2asc - converts direct access nad file to
#                    ascii receiver function model file.
#
#   Reading direct access file...
#   Finished reading direct access file
#
#   Writing ascii file...
#
# 3640 3426 273999.002912

# %%
big_c = np.int(128*(np.log(misfit_max) - np.log([misfit_cut]))/(np.log(misfit_cut) - np.log([misfit_min])))
colors1 = plt.cm.viridis(np.linspace(0., 1, 128))
colors2 = plt.cm.autumn_r(np.linspace(0, 1, big_c))
colors = np.vstack((colors1, colors2))
mymap = mcolors.LinearSegmentedColormap.from_list('my_colormap', colors)
plt.imshow([colors], extent=[0, 10, 0, 1])
plt.xticks([])
plt.yticks([])
plt.show()

# %%
# want the medain of all from data_NA_cut
# first Na2
nansen_calc = st.median(data_NA_cut[1,0:i_cut])
rossby_calc = st.median(data_NA_cut[2,0:i_cut])
thO_calc    = st.median(data_NA_cut[3,0:i_cut])
thA_O_calc  = st.median(data_NA_cut[4,0:i_cut])
print('Nansen set',np.sqrt(nansen_use),'and calculated',np.sqrt(data_NA['Na'][misfit_min_no]),np.sqrt(nansen_calc))
print('Rossby set',rossby_use,'and calculated',data_NA['Ro'][misfit_min_no],rossby_calc)
print('ThetaA set',np.rad2deg(ThetaA),'and calculated',
      np.rad2deg(data_NA['thA-O'][misfit_min_no]+data_NA['thO'][misfit_min_no]),np.rad2deg(thA_O_calc + thO_calc))
print('ThetaO set',np.rad2deg(ThetaO),'and calculated',np.rad2deg(data_NA['thO'][misfit_min_no]),np.rad2deg(thO_calc))
print('ThetaA - O set',np.rad2deg(ThetaA - ThetaO),'and calculated',np.rad2deg(data_NA['thA-O'][misfit_min_no]),np.rad2deg(thA_O_calc))
print('Ca calculated',(data_NA['Na'][misfit_min_no]/data_NA['Ro'][misfit_min_no])*(rhoi/rhoa))
print('Co calculated',(rhoi/rhoo)/data_NA['Ro'][misfit_min_no])
print('Ca calculated',(nansen_calc/rossby_calc*(rhoi/rhoa)))
print('Co calculated',(rhoi/rhoo)/rossby_calc)
# Out:
# Nansen set 0.02468120324 and calculated 0.0347462110165 0.0347341088125
# Rossby set 89.37621832358674 and calculated 357.504883 357.47699
# ThetaA set 5.0 and calculated 87.9438903718 87.6746679689
# ThetaO set 20.0 and calculated 84.0523149614 83.757762802
# ThetaA - O set -15.0 and calculated 3.89157541034 3.91690516686
# Ca calculated 0.0024773778501
# Co calculated 0.00249999993213
# Ca calculated 0.00247584556389
# Co calculated 0.00250019500062

# %%
# plot misfit
# cmin = 1e-10
# cmax = 1e2
plt.figure(figsize=[10,10])
plt.subplot(5,1,1)
cmin = misfit_min
# cmin = 1e-4
cmax = misfit_max
plt.scatter(data_NA['number'],data_NA['misfit'],c=np.log(data_NA['misfit']),s=4,cmap=mymap)
plt.plot(data_NA['number'],[misfit_cut for j in range(data_NA['number'][-1])],'--k')
plt.xlim([0,data_NA['number'][-1]])
plt.yscale('log')
plt.ylim([cmin,np.max(data_NA['misfit'])])
plt.clim(np.log([cmin,cmax]))
plt.ylabel('Total misfit')

plt.subplot(5,1,2)
plt.scatter(data_NA['number'],data_NA['Na'],c=np.log(data_NA['misfit']),s=4,cmap=mymap)
plt.plot(data_NA['number'],[data_NA['Na'][misfit_min_no] for j in range(data_NA['number'][-1])],'--r')
plt.plot(data_NA['number'],[nansen_use for j in range(data_NA['number'][-1])],'--k')
plt.xlim([0,data_NA['number'][-1]])
plt.ylim([np.min(data_NA['Na']),np.max(data_NA['Na'])])
plt.clim(np.log([cmin,cmax]))
plt.ylabel(r'Na$^2$')
# plt.savefig('misfit_all_100%.pdf')
plt.subplot(5,1,3)
plt.scatter(data_NA['number'],data_NA['Ro'],c=np.log(data_NA['misfit']),s=4,cmap=mymap)
plt.plot(data_NA['number'],[data_NA['Ro'][misfit_min_no] for j in range(data_NA['number'][-1])],'--r')
plt.plot(data_NA['number'],[rossby_use for j in range(data_NA['number'][-1])],'--k')
plt.xlim([0,data_NA['number'][-1]])
plt.ylim([np.min(data_NA['Ro']),np.max(data_NA['Ro'])])
plt.clim(np.log([cmin,cmax]))
plt.ylabel('Ro\'')
plt.subplot(5,1,4)
plt.scatter(data_NA['number'],data_NA['thA-O'],c=np.log(data_NA['misfit']),s=4,cmap=mymap)
plt.plot(data_NA['number'],[data_NA['thA-O'][misfit_min_no] for j in range(data_NA['number'][-1])],'--r')
plt.plot(data_NA['number'],[ThetaA-ThetaO for j in range(data_NA['number'][-1])],'--k')
plt.xlim([0,data_NA['number'][-1]])
plt.ylim([np.min(data_NA['thA-O']),np.max(data_NA['thA-O'])])
plt.clim(np.log([cmin,cmax]))
plt.ylabel(r'$\theta_{AW}$')
plt.subplot(5,1,5)
plt.scatter(data_NA['number'],data_NA['thO'],c=np.log(data_NA['misfit']),s=4,cmap=mymap)
plt.plot(data_NA['number'],[data_NA['thO'][misfit_min_no] for j in range(data_NA['number'][-1])],'--r')
plt.plot(data_NA['number'],[ThetaO for j in range(data_NA['number'][-1])],'--k')
plt.xlim([0,data_NA['number'][-1]])
plt.ylim([np.min(data_NA['thO']),np.max(data_NA['thO'])])
plt.clim(np.log([cmin,cmax]))
plt.ylabel(r'$\theta_{W}$')
plt.xlabel('Model Number')
plt.show()
# plot trade off
th1 = ThetaO
th2 = ThetaA - ThetaO
# x - Na y - Ro
plt.figure(figsize=[10,10])
# cmin = np.min(data_NA['misfit'])
# cmin = 1e-4
# cmax = np.max(data_NA['misfit'])#*0.1
# cmax = 1e7
# horizontal hists
plt.subplot(4,4,1)
plt.hist(data_NA['Ro'],bins=100,color='k',orientation='horizontal')
plt.ylim([np.min(data_NA['Ro']),np.max(data_NA['Ro'])])
plt.xscale('log')
plt.xlim([1e1,1e4])
plt.ylabel('Ro\'')
plt.subplot(4,4,5)
plt.hist(data_NA['thO'],bins=100,color='k',orientation='horizontal')
plt.ylim([np.min(data_NA['thO']),np.max(data_NA['thO'])])
plt.xscale('log')
plt.xlim([1e1,1e4])
plt.ylabel(r'$\theta_{W}$')
plt.subplot(4,4,9)
plt.hist(data_NA['thA-O'],bins=100,color='k',orientation='horizontal')
plt.ylim([np.min(data_NA['thA-O']),np.max(data_NA['thA-O'])])
plt.xscale('log')
plt.xlim([1e1,1e4])
plt.ylabel(r'$\theta_{AW}$')
# x - Na y - Ro
plt.subplot(4,4,2)
plt.scatter(data_NA['Na'],data_NA['Ro'],c=np.log(data_NA['misfit']),s=3,cmap=mymap)
plt.xlim([np.min(data_NA['Na']),np.max(data_NA['Na'])])
plt.ylim([np.min(data_NA['Ro']),np.max(data_NA['Ro'])])
plt.clim(np.log([cmin,cmax]))
# plt.ylabel('Ro')
plt.plot([np.min(data_NA['Na']),np.max(data_NA['Na'])],[i*rossby_use for i in [1,1]],'--k')
plt.plot([i*nansen_use for i in [1,1]],[np.min(data_NA['Ro']),np.max(data_NA['Ro'])],'--k')
plt.plot(data_NA['Na'][misfit_min_no],data_NA['Ro'][misfit_min_no],'xr')
# x - Na y - thA
plt.subplot(4,4,6)
plt.scatter(data_NA['Na'],data_NA['thO'],c=np.log(data_NA['misfit']),s=3,cmap=mymap)
plt.xlim([np.min(data_NA['Na']),np.max(data_NA['Na'])])
plt.ylim([np.min(data_NA['thO']),np.max(data_NA['thO'])])
plt.clim(np.log([cmin,cmax]))
# plt.ylabel('thO')
plt.plot([np.min(data_NA['Na']),np.max(data_NA['Na'])],[i*th1 for i in [1,1]],'--k')
plt.plot([i*nansen_use for i in [1,1]],[np.min(data_NA['thO']),np.max(data_NA['thO'])],'--k')
plt.plot(data_NA['Na'][misfit_min_no],data_NA['thO'][misfit_min_no],'xr')
# x - Ro y - thA
plt.subplot(4,4,7)
plt.scatter(data_NA['Ro'],data_NA['thO'],c=np.log(data_NA['misfit']),s=3,cmap=mymap)
plt.xlim([np.min(data_NA['Ro']),np.max(data_NA['Ro'])])
plt.ylim([np.min(data_NA['thO']),np.max(data_NA['thO'])])
plt.clim(np.log([cmin,cmax]))
plt.plot([np.min(data_NA['Ro']),np.max(data_NA['Ro'])],[i*th1 for i in [1,1]],'--k')
plt.plot([i*rossby_use for i in [1,1]],[np.min(data_NA['thO']),np.max(data_NA['thO'])],'--k')
plt.plot(data_NA['Ro'][misfit_min_no],data_NA['thO'][misfit_min_no],'xr')
# x - Na y - thO
plt.subplot(4,4,10)
plt.scatter(data_NA['Na'],data_NA['thA-O'],c=np.log(data_NA['misfit']),s=3,cmap=mymap)
plt.xlim([np.min(data_NA['Na']),np.max(data_NA['Na'])])
plt.ylim([np.min(data_NA['thA-O']),np.max(data_NA['thA-O'])])
plt.clim(np.log([cmin,cmax]))
# plt.ylabel('thA-O')
plt.plot([np.min(data_NA['Na']),np.max(data_NA['Na'])],[i*th2 for i in [1,1]],'--k')
plt.plot([i*nansen_use for i in [1,1]],[np.min(data_NA['thA-O']),np.max(data_NA['thA-O'])],'--k')
plt.plot(data_NA['Na'][misfit_min_no],data_NA['thA-O'][misfit_min_no],'xr')
# x - Ro y - thO
plt.subplot(4,4,11)
plt.scatter(data_NA['Ro'],data_NA['thA-O'],c=np.log(data_NA['misfit']),s=3,cmap=mymap)
plt.xlim([np.min(data_NA['Ro']),np.max(data_NA['Ro'])])
plt.ylim([np.min(data_NA['thA-O']),np.max(data_NA['thA-O'])])
plt.clim(np.log([cmin,cmax]))
plt.plot([np.min(data_NA['Ro']),np.max(data_NA['Ro'])],[i*th2 for i in [1,1]],'--k')
plt.plot([i*rossby_use for i in [1,1]],[np.min(data_NA['thA-O']),np.max(data_NA['thA-O'])],'--k')
plt.plot(data_NA['Ro'][misfit_min_no],data_NA['thA-O'][misfit_min_no],'xr')
# x - thA y - thO
plt.subplot(4,4,12)
plt.scatter(data_NA['thO'],data_NA['thA-O'],c=np.log(data_NA['misfit']),s=3,cmap=mymap)
plt.xlim([np.min(data_NA['thO']),np.max(data_NA['thO'])])
plt.ylim([np.min(data_NA['thA-O']),np.max(data_NA['thA-O'])])
plt.clim(np.log([cmin,cmax]))
plt.plot([np.min(data_NA['thO']),np.max(data_NA['thO'])],[i*th2 for i in [1,1]],'--k')
plt.plot([i*th1 for i in [1,1]],[np.min(data_NA['thA-O']),np.max(data_NA['thA-O'])],'--k')
plt.plot(data_NA['thO'][misfit_min_no],data_NA['thA-O'][misfit_min_no],'xr')
# bottom row histograms
plt.subplot(4,4,14)
plt.hist(data_NA['Na'],bins=100,color='k')
plt.xlim([np.min(data_NA['Na']),np.max(data_NA['Na'])])
plt.yscale('log')
plt.ylim([1e1,1e4])
plt.xlabel(r'Na$^2$')
plt.subplot(4,4,15)
plt.hist(data_NA['Ro'],bins=100,color='k')
plt.xlim([np.min(data_NA['Ro']),np.max(data_NA['Ro'])])
plt.yscale('log')
plt.ylim([1e1,1e4])
plt.xlabel('Ro\'')
plt.subplot(4,4,16)
plt.hist(data_NA['thO'],bins=100,color='k')
plt.xlim([np.min(data_NA['thO']),np.max(data_NA['thO'])])
plt.yscale('log')
plt.ylim([1e1,1e4])
plt.xlabel(r'$\theta_{W}$')
plt.show()
# plt.savefig('trade_off_all_100%.pdf')

# %%
# disassemble vectors
# forcing_1
vec_strd = 10
all_vecs = np.empty([np.int((data_NA['number'][-1]-it1)/vec_strd+1),nbals,7])
jj = 0
for j in range(it1,data_NA['number'][-1],vec_strd):
# for j in range(misfit_min_no,misfit_min_no+1):
    for i in range(nbals):
        all_vecs[jj,i,0],all_vecs[jj,i,1] = freedrift.wnd_mag_geo(
                          uo_i[i],vo_i[i],ugeo[i],vgeo[i],
                          data_NA['Na'][j],data_NA['Ro'][j]*hifc[i],
                          data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
        all_vecs[jj,i,2],all_vecs[jj,i,3] = freedrift.o_i_mag_geo(
                          uwind[i],vwind[i],ugeo[i],vgeo[i],
                          data_NA['Na'][j],data_NA['Ro'][j]*hifc[i],
                          data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
        all_vecs[jj,i,4],all_vecs[jj,i,5] = freedrift.geo_mag_geo(
                          uwind[i],vwind[i],uo_i[i],vo_i[i],
                          data_NA['Na'][j],data_NA['Ro'][j]*hifc[i],
                          data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
        all_vecs[jj,i,6] = data_NA['misfit'][j]
    jj += 1
#     print(jj,j)
j = misfit_min_no
for i in range(nbals):
    all_vecs[jj,i,0],all_vecs[jj,i,1] = freedrift.wnd_mag_geo(
                      uo_i[i],vo_i[i],ugeo[i],vgeo[i],
                      data_NA['Na'][j],data_NA['Ro'][j]*hifc[i],
                      data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
    all_vecs[jj,i,2],all_vecs[jj,i,3] = freedrift.o_i_mag_geo(
                      uwind[i],vwind[i],ugeo[i],vgeo[i],
                      data_NA['Na'][j],data_NA['Ro'][j]*hifc[i],
                      data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
    all_vecs[jj,i,4],all_vecs[jj,i,5] = freedrift.geo_mag_geo(
                      uwind[i],vwind[i],uo_i[i],vo_i[i],
                      data_NA['Na'][j],data_NA['Ro'][j]*hifc[i],
                      data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
    all_vecs[jj,i,6] = data_NA['misfit'][j]

# %%
# want arrows for the obs and best, scatter all the rest with mymap
wnd_range = np.max(wind_mag)
wnd_range = 0.99*np.max(np.maximum(all_vecs[-1,:,0:2],wnd_range))
wnd_scale = 0.04
plt.figure(figsize=[20,5*nbals])
plt.rc('text', usetex=True)
for nb in range(nbals):
# for nb in range(nbals):
    ax = plt.subplot(nbals/2,2,nb+1)
#     #   calculated vectors
    # wind
    plt.scatter(wnd_scale*all_vecs[:,nb,0],wnd_scale*all_vecs[:,nb,1],c=np.log(all_vecs[:,nb,6]),s=3,cmap=mymap)
    plt.scatter(all_vecs[:,nb,2],all_vecs[:,nb,3],c=np.log(all_vecs[:,nb,6]),s=3,cmap=mymap)
    plt.scatter(all_vecs[:,nb,4],all_vecs[:,nb,5],c=np.log(all_vecs[:,nb,6]),s=3,cmap=mymap)
    plt.clim(np.log([cmin,cmax]))
# #     for j in tqdm(range(0,data_NA['number'][-1],10)):
# #         plt.arrow(0,0,wnd_scale*all_vecs[j,nb,0],wnd_scale*all_vecs[j,nb,1],
# #                    alpha=0.009,color='k')
# #         plt.arrow(0,0,all_vecs[j,nb,2],all_vecs[j,nb,3],
# #                    alpha=0.009,color='b')
# #         plt.arrow(0,0,all_vecs[j,nb,4],all_vecs[j,nb,5],
# #                    alpha=0.009,color='g')
    plt.arrow(0,0,wnd_scale*all_vecs[-1,nb,0],wnd_scale*all_vecs[-1,nb,1],
               length_includes_head = 'true',linestyle='dashed',color='k',alpha = 0.7)
    plt.arrow(0,0,all_vecs[-1,nb,2],all_vecs[-1,nb,3],
               length_includes_head = 'true',linestyle='dashed',color='b',alpha = 0.7)
    plt.arrow(0,0,all_vecs[-1,nb,4],all_vecs[-1,nb,5],
               length_includes_head = 'true',linestyle='dashed',color='g',alpha = 0.7)
#     #   original vectors
    plt.arrow(0,0,wnd_scale*uwind[nb],wnd_scale*vwind[nb],
              color='k',length_includes_head = 'true',width=0.0015)
    plt.arrow(0,0,uo_i[nb],vo_i[nb],
              color='b',length_includes_head = 'true',width=0.0015)
    plt.arrow(0,0,ugeo[nb],vgeo[nb],
              color='g',length_includes_head = 'true',width=0.0015)
    plt.xlim([-wnd_range*wnd_scale,wnd_range*wnd_scale])
    plt.ylim([-wnd_range*wnd_scale,wnd_range*wnd_scale])
# #     plt.arrow(-wnd_scale/2,-wind_mag[nb]*wnd_scale/2,wnd_scale,0,
# #               color='k',length_includes_head = 'true',width=0.0015)
# #     plt.arrow(-wnd_scale/2,-3*wind_mag[nb]*wnd_scale/4,wnd_scale,0,
# # #               color='b',length_includes_head = 'true',width=0.0015)
# #     plt.arrow(-wnd_scale/2,-wnd_range*wnd_scale/2,wnd_scale,0,
# #               color='k',length_includes_head = 'true',width=0.0015)
# #     plt.arrow(-wnd_scale/2,-3*wnd_range*wnd_scale/4,wnd_scale,0,
# #               color='b',length_includes_head = 'true',width=0.0015)
# #     plt.text(wnd_scale,-wind_mag[nb]*wnd_scale/2,r'Wind $ = 1 $ m s$^{-1}$',fontsize=20,horizontalalignment='left')
# #     plt.text(wnd_scale,-3*wind_mag[nb]*wnd_scale/4,r'$\bf{U}_{WI}  = 2 $ cm s$^{-1}$',fontsize=20,horizontalalignment='left')
#     plt.text(wnd_scale,-wnd_range*wnd_scale/2,r'Wind $ = 1 $ m s$^{-1}$',fontsize=20,horizontalalignment='left')
#     plt.text(wnd_scale,-3*wnd_range*wnd_scale/4,r'$\bf{U}_{WI}  = 2 $ cm s$^{-1}$',fontsize=20,horizontalalignment='left')
    ax.axis('off')
plt.show()

# %%
# disassemble misfits
vec_strd = 10
all_misfits = np.empty([np.int((data_NA['number'][-1]-it1)/vec_strd),nbals,5])
# for j in tqdm(data_NA['number']-1):
jj = 0
for j in range(it1,data_NA['number'][-1],vec_strd):
    for i in range(nbals):
        all_misfits[jj,i,0] = freedrift.misfit_wnd_geo(
                          uwind[i],vwind[i],uo_i[i],vo_i[i],ugeo[i],vgeo[i],
                          data_NA['Na'][j],data_NA['Ro'][j]*hifc[i],
                          data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j]
                )*beta_a[i]/wind_sig_use[i]**2
        all_misfits[jj,i,1] = freedrift.misfit_o_i_geo(
                          uwind[i],vwind[i],uo_i[i],vo_i[i],ugeo[i],vgeo[i],
                          data_NA['Na'][j],data_NA['Ro'][j]*hifc[i],
                          data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j]
                )*beta_i[i]/o_i_sig_use[i]**2
        all_misfits[jj,i,2] = freedrift.misfit_geo_geo(
                          uwind[i],vwind[i],uo_i[i],vo_i[i],ugeo[i],vgeo[i],
                          data_NA['Na'][j],data_NA['Ro'][j]*hifc[i],
                          data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j]
                )*beta_g[i]/geo_sig_use[i]**2
        fb_ratio = np.max([wind_sig_use[i]/wind_mag[i],
                     o_i_sig_use[i]/o_i_mag[i], 
                     geo_sig_use[i]/geo_mag[i]]) 
        all_misfits[jj,i,3] = freedrift.misfit_fb_geo(
                          uwind[i],vwind[i],uo_i[i],vo_i[i],ugeo[i],vgeo[i],
                          data_NA['Na'][j]*data_NA['Ro'][j]/rhoi,
                          rhoi/data_NA['Ro'][j],rhoi*hifc[i],
                          data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j]
                )*beta_fb[i]/fb_ratio**2
        all_misfits[jj,i,4] = data_NA['misfit'][j]
    jj += 1

# %%
test_space = np.linspace(1e1,1e3,1000)
test_result = np.empty([1000,nbals])
i = 10
j = misfit_min_no
for k in range(1000):
    for i in range(nbals):
        test_result[k,i] =  freedrift.misfit_geo_geo(
                          uwind[i],vwind[i],uo_i[i],vo_i[i],ugeo[i],vgeo[i],
#                           data_NA['Na'][j],test_space[k]*hifc[i],
#                           data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j]
                          nansen_use,test_space[k]*hifc[i],
                          ThetaA,ThetaO
                )

plt.plot(test_space,test_result[:,:])
plt.ylim([0,0.0025])
# plt.axvline(x=data_NA['Ro'][j])
plt.axvline(x=rossby_use)
plt.show()

# %%
test_space = np.linspace(1e1,1e3,1000)
test_result = np.empty([1000,2])
i = 1
j = misfit_min_no
for k in range(1000):
    test_result[k,:] =  freedrift.geo_mag_geo(
                          uwind[i],vwind[i],uo_i[i],vo_i[i],
#                           data_NA['Na'][j],test_space[k]*hifc[i],
#                           data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j]
                          nansen_use,test_space[k]*hifc[i],
                          ThetaA,ThetaO
                )
plt.plot(test_space,test_result[:,0],'r')
plt.plot(test_space,test_result[:,1],'g')
plt.axhline(y=1*ugeo[i],c='r')
plt.axhline(y= vgeo[i],c='g')
plt.axvline(x=rossby_use)
plt.ylim([-0.05,0.05])
plt.show()

# %%
# plot misfit
plt.figure(figsize=[30,10])
cmin = 1e-10
# cmin = misfit_min*1e-3
# cmin = 1e-4
# cmax = misfit_max
cmax = 1e7
# cmin = 1e-12
for i in range(nbals):
    plt.subplot(1,nbals,i+1)
# for i in range(0,3):
#     plt.subplot(1,3,i+1)
    plt.plot(all_misfits[:,i,0],alpha = 1.0,c='k')
    plt.plot(np.sum(all_misfits[:,i,0:3],axis=1),c='k',alpha=0.5)
    plt.plot(all_misfits[:,i,1],alpha = 1.0,c='r')
    plt.plot(all_misfits[:,i,2],alpha = 1.0,c='b')
    plt.plot(all_misfits[:,i,3],alpha = 1.0,c='g')
    plt.plot(all_misfits[:,1,4],c=[1,0,1])
    plt.yscale('log')
    plt.ylim([cmin,cmax])
plt.show()

plt.plot(np.sum(all_misfits[:,:,0],axis=1),c='k')
# plt.plot(np.sum(all_misfits[:,:,1],axis=1),c='r')
plt.plot(np.sum(all_misfits[:,:,2],axis=1),c='b')
plt.plot(np.sum(all_misfits[:,:,3],axis=1),c='g')
plt.plot(all_misfits[:,0,4],c=[1,0,1])
plt.plot(np.sum(np.sum(all_misfits[:,:,0:4],axis=2),axis=1),c='k',alpha=0.5)
plt.ylim([cmin,cmax])
plt.yscale('log')
# plt.savefig('misfit_sep_100%.pdf')
plt.show()

# %%
# disassemble forces
# forcing_1
all_forces = np.empty([np.int((data_NA['number'][-1]-it1)/vec_strd+1),nbals,7])
# for j in tqdm(data_NA['number']-1):
# for j in range(data_NA['number'][-1]-10,data_NA['number'][-1]-1):
# for j in tqdm(data_NA['number']-1):
jj = 0
for j in range(it1,data_NA['number'][-1],vec_strd):
# for j in range(misfit_min_no-1,misfit_min_no+1):
    for i in range(nbals):
        [all_forces[jj,i,0],all_forces[jj,i,1],all_forces[jj,i,2],
         all_forces[jj,i,3],all_forces[jj,i,4],all_forces[jj,i,5]] = freedrift.force_bal(
                          uwind[i],vwind[i],ui_o[i],vi_o[i],
                          data_NA['Na'][j]/data_NA['Ro'][j]*rhoi,rhoi/data_NA['Ro'][j],rhoi*hifc[i],
                          data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
#         all_forces[jj,i,:] = freedrift.force_bal(
#                           all_vecs[jj,i,0],all_vecs[jj,i,1],all_vecs[jj,i,2],all_vecs[jj,i,3],
#                           data_NA['Na'][j]/data_NA['Ro'][j]*rhoi,rhoi/data_NA['Ro'][j],rhoi*hifc[i],
#                           data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
        all_forces[jj,i,6] = data_NA['misfit'][j]
    jj += 1
#     print(jj,j)
j = misfit_min_no
for i in range(nbals):
    [all_forces[jj,i,0],all_forces[jj,i,1],all_forces[jj,i,2],
     all_forces[jj,i,3],all_forces[jj,i,4],all_forces[jj,i,5]] = freedrift.force_bal(
                          uwind[i],vwind[i],ui_o[i],vi_o[i],
                          data_NA['Na'][j]/data_NA['Ro'][j]*rhoi,rhoi/data_NA['Ro'][j],rhoi*hifc[i],
                          data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
#         all_forces[jj,i,:] = freedrift.force_bal(
#                           all_vecs[jj,i,0],all_vecs[jj,i,1],all_vecs[jj,i,2],all_vecs[jj,i,3],
#                           data_NA['Na'][j]/data_NA['Ro'][j]*rhoi,rhoi/data_NA['Ro'][j],rhoi*hifc[i],
#                           data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
    all_forces[jj,i,6] = data_NA['misfit'][j]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-218-ebf850b340c8> in <module>()
#      11         [all_forces[jj,i,0],all_forces[jj,i,1],all_forces[jj,i,2],
#      12          all_forces[jj,i,3],all_forces[jj,i,4],all_forces[jj,i,5]] = freedrift.force_bal(
# ---> 13                           uwind[i],vwind[i],ui_o[i],vi_o[i],
#      14                           data_NA['Na'][j]/data_NA['Ro'][j]*rhoi,rhoi/data_NA['Ro'][j],rhoi*hifc[i],
#      15                           data_NA['thA-O'][j]+data_NA['thO'][j],data_NA['thO'][j])
#
# NameError: name 'ui_o' is not defined

# %%
leg_len = np.ndarray([nbals])
for i in range(nbals):
    leg_len[i] = 10.0**np.ceil(np.log10((np.hypot(all_forces[-1,i,0],all_forces[-1,i,1]))))
# leg_len

wnd_scale = 55
force_scale = 40
plt.figure(figsize=[10,10*nbals])
# plt.figure(figsize=[10,10])
for nb in range(nbals):
   
    ax = plt.subplot(nbals,1,nb+1)
#     plt.subplot(1,1,1)

    plt.arrow(0,0,force_scale*orig_forces[nb,0],force_scale*orig_forces[nb,1],
               color='k',width = force_magw[nb]*2,length_includes_head = 'true')
    plt.arrow(0,0,force_scale*orig_forces[nb,2],force_scale*orig_forces[nb,3],
               color='b',width = force_magw[nb]*2,length_includes_head = 'true')
    plt.arrow(0,0,force_scale*orig_forces[nb,4],force_scale*orig_forces[nb,5],
               color='g',width = force_magw[nb]*2,length_includes_head = 'true')

    plt.arrow(0,0,force_scale*all_forces[-1,nb,0],force_scale*all_forces[-1,nb,1],
               linestyle='dashed',color='k',alpha =0.5,width = force_magw[nb]*2,length_includes_head = 'true')
    plt.arrow(0,0,force_scale*all_forces[-1,nb,2],force_scale*all_forces[-1,nb,3],
               linestyle='dashed',color='b',alpha =0.5,width = force_magw[nb]*2,length_includes_head = 'true')
    plt.arrow(0,0,force_scale*all_forces[-1,nb,4],force_scale*all_forces[-1,nb,5],
               linestyle='dashed',color='g',alpha =0.5,width = force_magw[nb]*2,length_includes_head = 'true')
    plt.scatter(force_scale*all_forces[:,nb,0],force_scale*all_forces[:,nb,1],c=np.log(all_forces[:,nb,6]),s=3,cmap=mymap)
    plt.scatter(force_scale*all_forces[:,nb,2],force_scale*all_forces[:,nb,3],c=np.log(all_forces[:,nb,6]),s=3,cmap=mymap)
    plt.scatter(force_scale*all_forces[:,nb,4],force_scale*all_forces[:,nb,5],c=np.log(all_forces[:,nb,6]),s=3,cmap=mymap)
#     #   original vectors
#     plt.arrow(0,0,wnd_scale*uwind[nb],wnd_scale*vwind[nb],color='k')
#     plt.arrow(0,0,-ui_o[nb],-vi_o[nb],color='b')
    plt.xlim([-wnd_scale*force_magw[nb],wnd_scale*force_magw[nb]])
    plt.ylim([-wnd_scale*force_magw[nb],wnd_scale*force_magw[nb]])
    plt.arrow(-3*wnd_scale*force_magw[nb]/4,-3*wnd_scale*force_magw[nb]/4,leg_len[nb]*1e1,0,
              color='k',width = force_magw[nb]*2,length_includes_head = 'true')
    plt.text(-3*wnd_scale*force_magw[nb]/4+leg_len[nb]*1e1,-3*wnd_scale*force_magw[nb]/4,
             str(leg_len[nb])+' N m$^2$',fontsize=30,horizontalalignment='left')
#     plt.ylim([1.1*np.min(np.hstack((wnd_scale*uwind[nb],-ui_o[nb],wnd_scale*vwind[nb],-vi_o[nb],-0.02))),
#         1.1*np.max(np.hstack((wnd_scale*uwind[nb],-ui_o[nb],wnd_scale*vwind[nb],-vi_o[nb],0.02)))]) 
    ax.axis('off')
plt.show()
